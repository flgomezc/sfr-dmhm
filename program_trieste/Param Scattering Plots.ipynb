# %%
# Last modification: 2014-sep-03 Bogota
# %pylab inline
from random import *
from observational_data import *
from constants import *
from functions import *
# Out:
# Populating the interactive namespace from numpy and matplotlib
# observational_data.py:62: RuntimeWarning: divide by zero encountered in divide
#   Obs_data2_log10yerror = [array(log10(Bouwens[:,1]/(Bouwens[:,1]-Bouwens[:,2]))),

# %%
# Open the raw data from Markov Chain-MoteCarlo
# L_0 	 M_0 	 beta 	 gamma 	 chi_sqr 	 Number of Bins
if (Dust_Ext == 1):
    data = np.loadtxt('results_w_ext/0BB.dat',usecols=(0,1,2,3,4,5),skiprows=1000); 
else:
    data = np.loadtxt('results_wo_ext/13.dat',usecols=(0,1,2,3,4,5),skiprows=1000); 

BoxLength = 250.0 # Mpc h^{-1}

index = where( data[:,4] == data[:,4].min() )[0] 
L_min     = data[index,0][0]
M_min     = data[index,1][0]
beta_min  = data[index,2][0]
gamma_min = data[index,3][0]
bins      = data[index,5][0]

print L_min, M_min, beta_min ,gamma_min, bins

histo_0 = histogram(data[:,0], bins=30)
histo_1 = histogram(data[:,1], bins=30)
histo_2 = histogram(data[:,2], bins=30)
histo_3 = histogram(data[:,3], bins=30)

Lm = where( histo_0[0]==histo_0[0].max())[0][0]
Mm = where( histo_1[0]==histo_1[0].max())[0][0]
Bm = where( histo_2[0]==histo_2[0].max())[0][0]
Gm = where( histo_3[0]==histo_3[0].max())[0][0]

#Centro de la caja
LM = (histo_0[1][Lm]+ histo_0[1][Lm+1])/2.0
MM = (histo_1[1][Mm]+ histo_1[1][Mm+1])/2.0
BM = (histo_2[1][Bm]+ histo_2[1][Bm+1])/2.0
GM = (histo_3[1][Gm]+ histo_3[1][Gm+1])/2.0

print LM, MM, BM, GM
# Out:
# 18.0967366392 11.6857780318 0.768979195724 0.400981959499 18.0
# 18.111293886 11.6530883752 0.729360139806 0.503123332921

# %%
X = linspace(1000,10002,9002)
Y = data[:,4]

plot (X,Y)
figsize(6,6)
yscale("log")
ylabel("$\chi^2$", fontsize=20)
xlabel("MCMC steps", fontsize=20)

# %%
############## Scattering plots ########################

fig = figure(figsize=(10, 5))
fig.subplots_adjust(hspace=0.20, wspace=0.0,top=1.5, right=1.0, bottom=0.0)
ax1 = fig.add_subplot(221)
ax1.scatter(data[:,0], data[:,4], s=0.1)
ax1.set_xlabel("$\log_{10}(L_0)$",fontsize=20)
ax1.set_ylabel(" $\chi^2$ ",fontsize=20)
#ax1.set_ylim(0,5)
ax1.axis((17.6,18.2,0.7,1.2))
#ax1.set_yscale=("log")


ax2 = fig.add_subplot(222)
ax2.scatter(data[:,1], data[:,4], s=0.1)
ax2.set_xlabel("$\log_{10}(M_0)$",fontsize=20)
#ax2.set_ylabel(" $\chi^2$ ",fontsize=20)
#ax2.set_ylim(0,5)
ax2.axis((10.5,12.6,0.7,1.2))
#ax2.set_yscale=("log")
ax2.yaxis.set_major_formatter(plt.NullFormatter())

ax3 = fig.add_subplot(223)
ax3.scatter(data[:,2], data[:,4], s=0.1)
ax3.set_xlabel(r" $\beta $  ",fontsize=20)
ax3.set_ylabel(" $\chi^2$ ",fontsize=20)
ax3.axis((0.0,2.0,0.7,1.2))
#ax3.set_ylim(0,5)
#ax3.set_yscale=("log")
#ax.yaxis.set_major_formatter(plt.NullFormatter())

ax4 = fig.add_subplot(224)
ax4.scatter(data[:,3], data[:,4], s=0.1)
ax4.set_xlabel(r"$\gamma$",fontsize=20)
#ax4.set_ylabel(" $\chi^2$ ",fontsize=20)
ax4.yaxis.set_major_formatter(plt.NullFormatter())
ax4.axis((0.0,1.0,0.7,1.2))
#ax4.set_yscale=("log")



################## Histograms #############################

fig = figure(figsize=(10, 5))
fig.subplots_adjust(hspace=0.20, wspace=0.0,top=1.5, right=1.0, bottom=0.0)

ax1 = fig.add_subplot(221)
ax1.hist(data[:,0],bins=30)

ax2 = fig.add_subplot(222)
ax2.hist(data[:,1],bins=30)

ax3 = fig.add_subplot(223)
ax3.hist(data[:,2],bins=30)

ax4 = fig.add_subplot(224)
ax4.hist(data[:,3],bins=30)

ax1.axvline(x=L_min, color="blue")
#ax1.axvline(x=percentile(MCMC_raw[:,0], q=50), color="red")
#ax1.axvline(x=percentile(MCMC_raw[:,0], q=25), color="green")
#ax1.axvline(x=percentile(MCMC_raw[:,0], q=75), color="green")

ax2.axvline(x=M_min, color="blue"); 
#ax2.axvline(x=percentile(MCMC_raw[:,1], q=50), color="red")
#ax2.axvline(x=percentile(MCMC_raw[:,1], q=25), color="green")
#ax2.axvline(x=percentile(MCMC_raw[:,1], q=75), color="green")

ax3.axvline(x=beta_min, color="blue"); 
ax3.axvline(x=percentile(data[:,2], q=50), color="red")
ax3.axvline(x=percentile(data[:,2], q=25), color="green")
ax3.axvline(x=percentile(data[:,2], q=75), color="green")

ax4.axvline(x=gamma_min, color="blue");
ax4.axvline(x=percentile(data[:,3], q=50), color="red")
ax4.axvline(x=percentile(data[:,3], q=25), color="green")
ax4.axvline(x=percentile(data[:,3], q=75), color="green")

ax1.set_xlabel("$\log_{10}(L_0)$",fontsize=20)
ax2.set_xlabel("$\log_{10}(M_0)$",fontsize=20)
ax3.set_xlabel(r" $\beta $  ",fontsize=20)
ax4.set_xlabel(r"$\gamma$",fontsize=20)

print " Using '>' sign"
# Out:
#  Using '>' sign

# %%
nbins = 35
X = []

limits = zeros([2,4])
for i in range(4):
    limits[0,i]=data[:,i].min()
    limits[1,i]=data[:,i].max()
    X.append( linspace(limits[0,i],limits[1,i],nbins))
X = array(X)

# %%
H = []

aux= np.histogram2d(data[:,1],data[:,0],bins=nbins,normed=1.0)[0];aux = flipud(rot90(aux)); H.append(aux);
aux= np.histogram2d(data[:,2],data[:,0],bins=nbins,normed=1.0)[0];aux = flipud(rot90(aux)); H.append(aux);
aux= np.histogram2d(data[:,3],data[:,0],bins=nbins,normed=1.0)[0];aux = flipud(rot90(aux)); H.append(aux);
aux= np.histogram2d(data[:,2],data[:,1],bins=nbins,normed=1.0)[0];aux = flipud(rot90(aux)); H.append(aux);
aux= np.histogram2d(data[:,3],data[:,1],bins=nbins,normed=1.0)[0];aux = flipud(rot90(aux)); H.append(aux);
aux= np.histogram2d(data[:,3],data[:,2],bins=nbins,normed=1.0)[0];aux = flipud(rot90(aux)); H.append(aux);

H = array(H)

 
# H needs to be rotated and flipped
# H = np.rot90(H)
# H = np.flipud(H)

# %%
############## Scattering plots ########################

fig = figure(figsize=(10, 5))
fig.subplots_adjust(hspace=0.1, wspace=0.1,top=1.5, right=1.0, bottom=0.0)

ax0 = fig.add_subplot(331)
ax1 = fig.add_subplot(332)
ax2 = fig.add_subplot(333)
ax3 = fig.add_subplot(335)
ax4 = fig.add_subplot(336)
ax5 = fig.add_subplot(339)

ax0.contourf(X[1],X[0],H[0])
ax1.contourf(X[2],X[0],H[1])
ax2.contourf(X[3],X[0],H[2])
ax3.contourf(X[2],X[1],H[3])
ax4.contourf(X[3],X[1],H[4])
ax5.contourf(X[3],X[2],H[5])

lblsz = 20 # label size
fntsz = 30 # font size

ax1.yaxis.set_major_formatter(plt.NullFormatter())
ax2.yaxis.set_major_formatter(plt.NullFormatter())
ax4.yaxis.set_major_formatter(plt.NullFormatter())

ax1.xaxis.set_major_formatter(plt.NullFormatter())
ax2.xaxis.set_major_formatter(plt.NullFormatter())
ax4.xaxis.set_major_formatter(plt.NullFormatter())

ax0.tick_params(axis='both', labelsize=lblsz)
ax3.tick_params(axis='both', labelsize=lblsz)
ax5.tick_params(axis='both', labelsize=lblsz)

ax0.set_xticks( [11.4,11.8,12.2])
ax0.set_yticks( [17.9,18.0,18.1,18.2])

ax3.set_xticks( [0.5,0.8,1.1])
ax3.set_yticks( [11.4,11.8,12.2])

ax5.set_xticks( [0.2,0.4,0.6,0.8])
ax5.set_yticks( [0.5,0.8,1.1])

ax0.set_ylabel("$\log_{10}(L_0)$", fontsize=fntsz,rotation=0)
ax3.set_ylabel("$\log_{10}(M_0)$", fontsize=fntsz,rotation=0)
ax5.set_ylabel(r"$\beta$"        , fontsize=fntsz,rotation=0)
ax5.set_xlabel(r"$\gamma$"       , fontsize=fntsz)

#ax6 = fig.add_subplot(337)
#ax6.hist2d(data[:,0],data[:,1],nbins,normed=1)
#ax6.colorbar()

#cbar_ax = fig.add_axes([0.95, 0.05, 0.03, 0.93])
#fig.colorbar(H[0], cax=cbar_ax)

# %%
fig = figure(figsize=(9, 9))
#fig.subplots_adjust(hspace=0.1, wspace=0.1,top=1.0, right=1.0, bottom=0.0)
fig.subplots_adjust(top=1.0, right=1.0, bottom=0.0)

gs1 = GridSpec(3,3)       #This grid contains the 6 graphs
gs1.update( left=0.01, right=0.92, wspace=0.1, hspace=0.1)
ax0 = plt.subplot(gs1[0,0])
ax1 = plt.subplot(gs1[0,1])
ax2 = plt.subplot(gs1[0,2])
ax3 = plt.subplot(gs1[1,1])
ax4 = plt.subplot(gs1[1,2])
ax5 = plt.subplot(gs1[2,2])

gs2 = GridSpec(1,1)        #This grid contains only the colorbar
gs2.update( left = 0.95, right=0.99)
ax6 = plt.subplot(gs2[:,:])

ax0.contourf(X[1],X[0],H[0])
ax1.contourf(X[2],X[0],H[1])
ax2.contourf(X[3],X[0],H[2])
ax3.contourf(X[2],X[1],H[3])
ax4.contourf(X[3],X[1],H[4])
im = ax5.contourf(X[3],X[2],H[5])

fig.colorbar(im,ax6)

lblsz = 15 # label size
fntsz = 30 # font size

ax1.yaxis.set_major_formatter(plt.NullFormatter())
ax2.yaxis.set_major_formatter(plt.NullFormatter())
ax4.yaxis.set_major_formatter(plt.NullFormatter())

ax1.xaxis.set_major_formatter(plt.NullFormatter())
ax2.xaxis.set_major_formatter(plt.NullFormatter())
ax4.xaxis.set_major_formatter(plt.NullFormatter())

ax0.tick_params(axis='both', labelsize=lblsz)
ax3.tick_params(axis='both', labelsize=lblsz)
ax5.tick_params(axis='both', labelsize=lblsz)

ax0.set_xticks( [11.4,11.8,12.2])
ax0.set_yticks( [17.9,18.0,18.1,18.2])

ax3.set_xticks( [0.5,0.8,1.1])
ax3.set_yticks( [11.4,11.8,12.2])

ax5.set_xticks( [0.2,0.4,0.6,0.8])
ax5.set_yticks( [0.5,0.8,1.1])

ax0.set_ylabel("$\log_{10}(L_0)$", fontsize=fntsz,rotation=0)
ax3.set_ylabel("$\log_{10}(M_0)$", fontsize=fntsz,rotation=0)
ax5.set_ylabel(r"$\beta$"        , fontsize=fntsz,rotation=0)
ax5.set_xlabel(r"$\gamma$"       , fontsize=fntsz)
ax6.set_ylabel("MCMC points density", fontsize = fntsz)

# %% [markdown]
# http://snowball.millersville.edu/~adecaria/ESCI386P/esci386-lesson13-2Dplots.pdf
#
# Contour plots
#
#
# http://stackoverflow.com/questions/18266642/multiple-imshow-subplots-each-with-colorbar
#
# Multiple imshow subplots wach with colorbar

# %%
############## Scattering plots ########################

fig = figure(figsize=(10, 5))
fig.subplots_adjust(hspace=0.3, wspace=0.3,top=1.5, right=1.0, bottom=0.0)

ax1 = fig.add_subplot(331) # L* vs M*
ax1.scatter(MCMC_raw[:,0], MCMC_raw[:,1], s=0.01)
ax1.set_xlabel("$\log_{10}(L_0)$",fontsize=20)
ax1.set_ylabel(" $\log_{10}(M_0)$ ",fontsize=20)
