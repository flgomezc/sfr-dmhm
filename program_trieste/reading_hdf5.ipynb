# %%
# %pylab inline
import h5py
from matplotlib.colors import LogNorm
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
f = h5py.File("../data/v_gonzalez/sfr.z6.hdf5", 'r')

# %%
def printname(name):
     print name
f.visit(printname)
# Out:
# Info
# Info/IMF
# Info/Model
# Info/Volume
# Info/h
# z6
# z6/logM
# z6/logSFR
# z6/logSM

# %%
group = f['z6']

logM   = group['logM'].value
logSFR = group['logSFR'].value

group1 = f['Info']
IMF    = group1['IMF'].value
Model  = group1['Model'].value

print "IMF = ", IMF, "\nModel = ", Model
# Out:
# IMF =  Kennicutt
# Model =  V. Gonzalez-Perez et al. 2014 (http://arxiv.org/abs/1309.7057)

# %%
hist2d(logM, logSFR, bins=100);

# %%
hist2d(logM, logSFR, bins=100, range=np.array([(10,14),(-4,3)]));colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x988e3f8>

# %%
hist2d(logM, logSFR, bins=100, norm=LogNorm()); colorbar()
#xlim([10,14])
#ylim([-4,3])
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x99608c0>

# %%
logM.shape
# Out:
# (29863228,)
