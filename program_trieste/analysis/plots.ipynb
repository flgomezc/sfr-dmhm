# %%
# Last modification: 2014-ago-13 - Bogota
# %pylab inline
from random import *
from observational_data import *

hpl  = 0.6777            # Using h from 2013-Planck
Mag0 = -4.61455/0.2587   # Limit magnitude to apply dust attenuation

# X (Mpc h^-1), Y (Mpc h^-1), Z (Mpc h^-1), Halo mass (Solar Mass)
data = np.loadtxt(
    #'../../data/MD_3840_Planck1/BDM/new_reduced_catshortV_007.dat',usecols=(0,1,2,3), skiprows=17); BoxLength = 1000.0/ # Mpc h^{-1}
    '../../data/MD_3840_Planck1/BDM/Small_Cells/0.dat', usecols=(0,1,2,3), skiprows=0); BoxLength = 250.0 # Mpc h^{-1}
    
def Luminosity(M,L_0,M_0,beta,gamma):
    return L_0*M*( (M/M_0)**(-beta) + (M/M_0)**gamma)**(-1)

def StarFormationRate(M,L_0,M_0,beta,gamma):
    return Luminosity(M,L_0,M_0,beta,gamma) * 1.4e-28
# Out:
# Populating the interactive namespace from numpy and matplotlib
# observational_data.py:62: RuntimeWarning: divide by zero encountered in divide
#   Obs_data2_log10yerror = [array(log10(Bouwens[:,1]/(Bouwens[:,1]-Bouwens[:,2]))),

# %%
#MCMC_reg = open("MCMC_reg.dat", "w")
histo1 = []
#17.9443914606	11.2542542043	1.07046052253	0.142423739873	0.868519374753	18
L_0   = 10.0**(17.94)
M_0   = 10.0**(11.25)
beta  =  1.0704
gamma =  0.1424

M       = data[:,3]
log10_M = log10(M[:])
L       = np.zeros(M.size)
L_R     = np.zeros(M.size)
L[:] = Luminosity( M[:], L_0, M_0, beta, gamma)
Magnitude_UV_galaxy_list = 51.82 - 2.5 * log10(L[:])
    ### Dust Extinction
Mag = Magnitude_UV_galaxy_list
Mag[Mag< Mag0] = ( Mag[Mag< Mag0]-4.61455)/1.2587

HIST00 = histogram(Magnitude_UV_galaxy_list,10)
HIST0 = 1.0*HIST00[0]

HIST1 = 1.0*histogram(Magnitude_UV_galaxy_list,bins=HIST1_bins)[0]
HIST2 = 1.0*histogram(Magnitude_UV_galaxy_list,bins=HIST2_bins)[0]
HIST3 = 1.0*histogram(Magnitude_UV_galaxy_list,bins=HIST3_bins)[0]

BinSizeHist0 = HIST00[1][1]-HIST00[1][2]
for i in range(len(HIST0)):
    HIST0[i] = HIST0[i]/(BinSizeHist0*BoxLength**3)

for i in range(len(HIST1)):
    HIST1[i] = HIST1[i]/((HIST1_bins[i+1]-HIST1_bins[i])*BoxLength**3)
for i in range(len(HIST2)):
    HIST2[i] = HIST2[i]*1.0/(1.0*(HIST2_bins[i+1]-HIST2_bins[i])*BoxLength**3)
for i in range(len(HIST3)):
    HIST3[i] = HIST3[i]/((HIST3_bins[i+1]-HIST3_bins[i])*BoxLength**3)
NOB = 0
chi_sqr=0.0
for i in range(len(HIST1)):
    if (HIST1[i] != 0.0):
        chi_sqr = chi_sqr + (( log10(HIST1[i])-Obs_data1_log10[i,1] )**2 )/(2*sigma1[i]**2)
        NOB += 1
for i in range(len(HIST2)):
    if (HIST2[i] != 0.0):
        chi_sqr = chi_sqr + (( log10(HIST2[i])-Obs_data2_log10[i,1] )**2 )/(2*sigma2[i]**2)
        NOB += 1
for i in range(len(HIST3)):
    if (HIST3[i] != 0.0):
        chi_sqr = chi_sqr + (( log10(HIST3[i])-Obs_data3_log10[i,1] )**2 )/(2*sigma3[i]**2)
        NOB += 1

histo1.append([HIST1, HIST2, HIST3]);

if NOB > 4:
    NDF = NOB-4
else:
    NDF = 1.0e-10

chi_sqr = chi_sqr / NDF

histo1[0]
# Out:
# [array([  3.84000000e-07,   4.73600000e-06,   2.48320000e-05,
#           8.06400000e-05,   2.22208000e-04]),
#  array([  4.46511628e-07,   4.22400000e-06,   2.35520000e-05,
#           7.89760000e-05,   2.12224000e-04,   4.72320000e-04,
#           9.08672000e-04]),
#  array([  3.13725490e-06,   9.98400000e-06,   2.25280000e-05,
#           4.60800000e-05,   8.42240000e-05,   1.29333333e-04])]

# %%
figure(figsize(9,7))
plot()
ylabel(r"$\Phi(M_{1350})($ Mpc$^{-3}$mag$^{-1})$",fontsize=20)
xlabel('$M_{1350}$',fontsize=20)
plt.grid(True)
title("Cosmic Variance",fontsize=25)
tick_params(axis="both", labelsize=15)


for K in range (1):
    scatter( Obs_data1[:,0] , histo1[K][0],s=10, color="red")
    scatter( Obs_data2[:,0] , histo1[K][1],s=10, color="black")
    scatter( Obs_data3[:,0] , histo1[K][2],s=10, color="blue")

errorbar(Obs_data2[:,0],Obs_data2[:,1], xerr=Obs_data2xerror, yerr=Obs_data2yerror, fmt='.', color="0.40", label="Bouwens et al 2014")
errorbar(Obs_data1[:,0],Obs_data1[:,1], xerr=0.25, yerr=Obs_data1yerror, fmt='.', color="0.40", label="Willott et al 2013")
errorbar(Obs_data3[:,0],Obs_data3[:,1], xerr=Obs_data3xerror, yerr=Obs_data3yerror, fmt='.', color="0.40", label="McLure et al 2009")


plt.axis([-23,-18,10**-9,0.01])
yscale("log")

# %%
parameters = np.loadtxt('../analysis/best_parameters.dat',usecols=(0,1,2,3), skiprows=0);

# %%
#MCMC_reg = open("MCMC_reg.dat", "w")
histo1 = []

#for K in range(parameters.shape[0]):
for K in range(64):

    L_0  = 10**parameters[K,0]
    M_0  = 10**parameters[K,1]
    beta = parameters[K,2]
    gamma= parameters[K,3]

    M       = data[:,3]
    log10_M = log10(M[:])
    L       = np.zeros(M.size)
    L_R     = np.zeros(M.size)
    L[:] = Luminosity( M[:], L_0, M_0, beta, gamma)
    Magnitude_UV_galaxy_list = 51.82 - 2.5 * log10(L[:])

    HIST00 = histogram(Magnitude_UV_galaxy_list,10)
    HIST0 = 1.0*HIST00[0]

    HIST1 = 1.0*histogram(Magnitude_UV_galaxy_list,bins=HIST1_bins)[0]
    HIST2 = 1.0*histogram(Magnitude_UV_galaxy_list,bins=HIST2_bins)[0]
    HIST3 = 1.0*histogram(Magnitude_UV_galaxy_list,bins=HIST3_bins)[0]

    BinSizeHist0 = HIST00[1][1]-HIST00[1][2]
    for i in range(len(HIST0)):
        HIST0[i] = HIST0[i]/(BinSizeHist0*BoxLength**3)

    for i in range(len(HIST1)):
        HIST1[i] = HIST1[i]/((HIST1_bins[i+1]-HIST1_bins[i])*BoxLength**3)
    for i in range(len(HIST2)):
        HIST2[i] = HIST2[i]*1.0/(1.0*(HIST2_bins[i+1]-HIST2_bins[i])*BoxLength**3)
    for i in range(len(HIST3)):
        HIST3[i] = HIST3[i]/((HIST3_bins[i+1]-HIST3_bins[i])*BoxLength**3)
    NOB = 0
    chi_sqr=0.0
    for i in range(len(HIST1)):
        if (HIST1[i] != 0.0):
            chi_sqr = chi_sqr + (( log10(HIST1[i])-Obs_data1_log10[i,1] )**2 )/(2*sigma1[i]**2)
            NOB += 1
    for i in range(len(HIST2)):
        if (HIST2[i] != 0.0):
            chi_sqr = chi_sqr + (( log10(HIST2[i])-Obs_data2_log10[i,1] )**2 )/(2*sigma2[i]**2)
            NOB += 1
    for i in range(len(HIST3)):
        if (HIST3[i] != 0.0):
            chi_sqr = chi_sqr + (( log10(HIST3[i])-Obs_data3_log10[i,1] )**2 )/(2*sigma3[i]**2)
            NOB += 1

    histo1.append([HIST1, HIST2, HIST3]);

    if NOB > 4:
        NDF = NOB-4
    else:
        NDF = 1.0e-10

    chi_sqr = chi_sqr / NDF
#MCMC_reg.write("# L_0 \t M_0 \t beta \t gamma \t chi_sqr \t Number of Bins")
#MCMC_reg.write(str(log10(L_0))+"\t"+str(log10(M_0))+"\t"+str(beta)+"\t"+str(gamma)+"\t"+str(chi_sqr)+"\t"+str(NOB)+"\n")

# %%
HIST00BINS=np.zeros(HIST00[1].size-1)
for i in range(HIST00BINS.size):
    HIST00BINS[i]=HIST00[1][i]
print HIST00BINS
# Out:
# [-23.57563691 -22.97875171 -22.38186651 -21.7849813  -21.1880961
#  -20.59121089 -19.99432569 -19.39744049 -18.80055528 -18.20367008]

# %%
histo1
# Out:
# [[array([  2.18600000e-06,   9.37400000e-06,   3.30800000e-05,
#            9.49600000e-05,   2.31248000e-04]),
#   array([  2.21627907e-06,   8.85000000e-06,   3.15280000e-05,
#            9.13560000e-05,   2.26548000e-04,   4.97748000e-04,
#            1.01934600e-03]),
#   array([  6.66862745e-06,   1.71440000e-05,   3.22400000e-05,
#            5.74400000e-05,   9.12440000e-05,   1.47979167e-04])],
#  [array([  1.28000000e-06,   6.47400000e-06,   2.48160000e-05,
#            7.48000000e-05,   1.90992000e-04]),
#   array([  1.32093023e-06,   6.13600000e-06,   2.35440000e-05,
#            7.23020000e-05,   1.86864000e-04,   4.14540000e-04,
#            8.51324000e-04]),
#   array([  4.42352941e-06,   1.24400000e-05,   2.36800000e-05,
#            4.48720000e-05,   7.35360000e-05,   1.19520833e-04])],
#  [array([  3.81200000e-06,   1.31260000e-05,   4.04040000e-05,
#            1.00220000e-04,   2.30246000e-04]),
#   array([  3.95348837e-06,   1.25020000e-05,   3.88600000e-05,
#            9.73260000e-05,   2.23678000e-04,   4.63928000e-04,
#            9.36310000e-04]),
#   array([  9.80784314e-06,   2.28320000e-05,   3.96600000e-05,
#            6.27960000e-05,   9.96800000e-05,   1.51850000e-04])],
#  [array([  1.62800000e-06,   8.03400000e-06,   3.21960000e-05,
#            1.02772000e-04,   2.82038000e-04]),
#   array([  1.66511628e-06,   7.59600000e-06,   3.04120000e-05,
#            9.88140000e-05,   2.68258000e-04,   6.56060000e-04,
#            1.37982800e-03]),
#   array([  5.58823529e-06,   1.54720000e-05,   3.10080000e-05,
#            5.86440000e-05,   1.00808000e-04,   1.65941667e-04])],
#  [array([  1.39400000e-06,   7.65400000e-06,   2.99360000e-05,
#            8.67560000e-05,   1.99212000e-04]),
#   array([  1.42325581e-06,   7.23400000e-06,   2.84180000e-05,
#            8.34940000e-05,   1.95126000e-04,   3.89032000e-04,
#            7.02076000e-04]),
#   array([  5.18431373e-06,   1.50120000e-05,   2.94120000e-05,
#            5.34240000e-05,   8.44400000e-05,   1.31591667e-04])],
#  [array([  1.11800000e-06,   6.16600000e-06,   2.50420000e-05,
#            8.08480000e-05,   2.11782000e-04]),
#   array([  1.14418605e-06,   5.82200000e-06,   2.38220000e-05,
#            7.67320000e-05,   2.03718000e-04,   4.64980000e-04,
#            9.53672000e-04]),
#   array([  4.14705882e-06,   1.20280000e-05,   2.42080000e-05,
#            4.63360000e-05,   7.75120000e-05,   1.31529167e-04])],
#  [array([  5.87400000e-06,   1.92880000e-05,   5.14480000e-05,
#            1.09036000e-04,   1.95788000e-04]),
#   array([  5.99069767e-06,   1.84900000e-05,   4.97880000e-05,
#            1.05384000e-04,   1.96342000e-04,   3.27682000e-04,
#            4.85752000e-04]),
#   array([  1.46313725e-05,   3.23920000e-05,   5.24320000e-05,
#            7.37480000e-05,   1.08108000e-04,   1.49695833e-04])],
#  [array([  2.15800000e-06,   9.00000000e-06,   3.19480000e-05,
#            9.20860000e-05,   2.35628000e-04]),
#   array([  2.19534884e-06,   8.52200000e-06,   3.04200000e-05,
#            8.86200000e-05,   2.25252000e-04,   5.21256000e-04,
#            1.05520000e-03]),
#   array([  6.48627451e-06,   1.65040000e-05,   3.12880000e-05,
#            5.53760000e-05,   8.89720000e-05,   1.45966667e-04])],
#  [array([  1.19400000e-06,   6.51200000e-06,   2.62980000e-05,
#            8.38380000e-05,   2.21412000e-04]),
#   array([  1.22325581e-06,   6.12600000e-06,   2.51000000e-05,
#            8.08480000e-05,   2.11782000e-04,   4.82952000e-04,
#            9.69226000e-04]),
#   array([  4.36078431e-06,   1.28280000e-05,   2.52560000e-05,
#            4.89440000e-05,   8.08400000e-05,   1.37291667e-04])],
#  [array([  1.25400000e-06,   6.42400000e-06,   2.55440000e-05,
#            8.33840000e-05,   2.22620000e-04]),
#   array([  1.29069767e-06,   6.08000000e-06,   2.43700000e-05,
#            7.91860000e-05,   2.14142000e-04,   5.15868000e-04,
#            1.09074200e-03]),
#   array([  4.34313725e-06,   1.25960000e-05,   2.46600000e-05,
#            4.79320000e-05,   8.09480000e-05,   1.35383333e-04])],
#  [array([  1.56000000e-06,   7.01200000e-06,   2.45760000e-05,
#            6.99200000e-05,   1.67646000e-04]),
#   array([  1.60465116e-06,   6.63800000e-06,   2.34340000e-05,
#            6.65180000e-05,   1.61950000e-04,   3.47614000e-04,
#            7.00080000e-04]),
#   array([  4.97058824e-06,   1.29080000e-05,   2.40040000e-05,
#            4.24600000e-05,   6.75800000e-05,   1.07579167e-04])],
#  [array([  1.28600000e-06,   6.35200000e-06,   2.49020000e-05,
#            8.05820000e-05,   2.16312000e-04]),
#   array([  1.32558140e-06,   5.95600000e-06,   2.36780000e-05,
#            7.76300000e-05,   2.07044000e-04,   4.92362000e-04,
#            1.01811600e-03]),
#   array([  4.29019608e-06,   1.21880000e-05,   2.40880000e-05,
#            4.64760000e-05,   7.83840000e-05,   1.29779167e-04])],
#  [array([  2.19000000e-06,   8.72200000e-06,   2.99780000e-05,
#            8.58260000e-05,   2.17350000e-04]),
#   array([  2.24418605e-06,   8.26200000e-06,   2.86400000e-05,
#            8.24380000e-05,   2.07764000e-04,   4.78422000e-04,
#            1.01811600e-03]),
#   array([  6.36666667e-06,   1.56640000e-05,   2.94080000e-05,
#            5.23400000e-05,   8.26320000e-05,   1.33758333e-04])],
#  [array([  1.85800000e-06,   7.97800000e-06,   2.95360000e-05,
#            9.15540000e-05,   2.51720000e-04]),
#   array([  1.90930233e-06,   7.60000000e-06,   2.79560000e-05,
#            8.82140000e-05,   2.40024000e-04,   6.07740000e-04,
#            1.39516600e-03]),
#   array([  5.72352941e-06,   1.48280000e-05,   2.84840000e-05,
#            5.31480000e-05,   8.95440000e-05,   1.50050000e-04])],
#  [array([  3.21200000e-06,   1.22160000e-05,   3.84960000e-05,
#            9.34960000e-05,   2.01722000e-04]),
#   array([  3.28372093e-06,   1.15460000e-05,   3.72200000e-05,
#            8.90920000e-05,   1.92858000e-04,   3.70284000e-04,
#            6.34970000e-04]),
#   array([  8.93725490e-06,   2.15760000e-05,   3.77000000e-05,
#            6.01560000e-05,   9.30600000e-05,   1.34833333e-04])],
#  [array([  2.40400000e-06,   1.05500000e-05,   3.86620000e-05,
#            1.08440000e-04,   2.73124000e-04]),
#   array([  2.45813953e-06,   9.98000000e-06,   3.70320000e-05,
#            1.05412000e-04,   2.65024000e-04,   5.96600000e-04,
#            1.21183200e-03]),
#   array([  7.48627451e-06,   1.94920000e-05,   3.75920000e-05,
#            6.45360000e-05,   1.08684000e-04,   1.75429167e-04])],
#  [array([  1.89800000e-06,   7.92000000e-06,   2.60360000e-05,
#            7.02680000e-05,   1.64478000e-04]),
#   array([  1.96046512e-06,   7.54800000e-06,   2.47420000e-05,
#            6.78660000e-05,   1.57958000e-04,   3.36528000e-04,
#            6.49862000e-04]),
#   array([  5.76078431e-06,   1.38760000e-05,   2.53240000e-05,
#            4.54280000e-05,   6.74160000e-05,   1.05762500e-04])],
#  [array([  2.45800000e-06,   1.07420000e-05,   3.84260000e-05,
#            1.04742000e-04,   2.56684000e-04]),
#   array([  2.52558140e-06,   1.01480000e-05,   3.68160000e-05,
#            1.01934000e-04,   2.43280000e-04,   5.18408000e-04,
#            1.01840400e-03]),
#   array([  7.67254902e-06,   1.97840000e-05,   3.74800000e-05,
#            6.39280000e-05,   1.03192000e-04,   1.65258333e-04])],
#  [array([  3.67000000e-06,   1.42080000e-05,   4.80280000e-05,
#            1.27356000e-04,   2.99828000e-04]),
#   array([  3.73953488e-06,   1.35840000e-05,   4.56780000e-05,
#            1.23754000e-04,   2.90424000e-04,   6.33698000e-04,
#            1.18656000e-03]),
#   array([  1.04000000e-05,   2.59840000e-05,   4.76440000e-05,
#            7.76080000e-05,   1.24844000e-04,   1.98012500e-04])],
#  [array([  1.50000000e-06,   7.86600000e-06,   3.11500000e-05,
#            9.49320000e-05,   2.41398000e-04]),
#   array([  1.55348837e-06,   7.44800000e-06,   2.98100000e-05,
#            9.11680000e-05,   2.30704000e-04,   4.97748000e-04,
#            9.67714000e-04]),
#   array([  5.36862745e-06,   1.53400000e-05,   3.05840000e-05,
#            5.70200000e-05,   9.28760000e-05,   1.50208333e-04])],
#  [array([  1.92600000e-06,   7.68200000e-06,   2.56880000e-05,
#            7.18240000e-05,   1.74650000e-04]),
#   array([  1.96279070e-06,   7.32600000e-06,   2.43840000e-05,
#            6.94220000e-05,   1.67646000e-04,   3.70604000e-04,
#            7.65230000e-04]),
#   array([  5.62156863e-06,   1.35920000e-05,   2.49400000e-05,
#            4.44120000e-05,   6.92320000e-05,   1.11916667e-04])],
#  [array([  2.16600000e-06,   9.45200000e-06,   3.54420000e-05,
#            1.09306000e-04,   3.05630000e-04]),
#   array([  2.19069767e-06,   8.85000000e-06,   3.37880000e-05,
#            1.04800000e-04,   2.90840000e-04,   7.22444000e-04,
#            1.70228000e-03]),
#   array([  6.66078431e-06,   1.75480000e-05,   3.42800000e-05,
#            6.22800000e-05,   1.07376000e-04,   1.81408333e-04])],
#  [array([  2.11400000e-06,   8.85000000e-06,   3.21520000e-05,
#            9.50160000e-05,   2.50322000e-04]),
#   array([  2.14186047e-06,   8.41200000e-06,   3.02560000e-05,
#            9.17600000e-05,   2.44236000e-04,   5.75820000e-04,
#            1.21188000e-03]),
#   array([  6.37254902e-06,   1.63960000e-05,   3.12560000e-05,
#            5.58400000e-05,   9.31280000e-05,   1.54608333e-04])],
#  [array([  2.06800000e-06,   8.47800000e-06,   2.87960000e-05,
#            7.94860000e-05,   1.92010000e-04]),
#   array([  2.11395349e-06,   8.03600000e-06,   2.76480000e-05,
#            7.64940000e-05,   1.84032000e-04,   3.93168000e-04,
#            7.51094000e-04]),
#   array([  6.16274510e-06,   1.52640000e-05,   2.81840000e-05,
#            5.00640000e-05,   7.77880000e-05,   1.20933333e-04])],
#  [array([  3.58400000e-06,   1.34420000e-05,   4.45160000e-05,
#            1.16132000e-04,   2.76280000e-04]),
#   array([  3.66511628e-06,   1.28720000e-05,   4.28480000e-05,
#            1.12442000e-04,   2.68338000e-04,   5.76018000e-04,
#            1.08558200e-03]),
#   array([  9.93921569e-06,   2.41040000e-05,   4.46520000e-05,
#            7.03000000e-05,   1.14740000e-04,   1.77487500e-04])],
#  [array([  1.54200000e-06,   7.56600000e-06,   2.92060000e-05,
#            9.14500000e-05,   2.41268000e-04]),
#   array([  1.57906977e-06,   7.11800000e-06,   2.77140000e-05,
#            8.81140000e-05,   2.30642000e-04,   5.39686000e-04,
#            1.14725800e-03]),
#   array([  5.22745098e-06,   1.45360000e-05,   2.81320000e-05,
#            5.38120000e-05,   8.92640000e-05,   1.47954167e-04])],
#  [array([  6.90000000e-07,   4.23400000e-06,   1.94660000e-05,
#            7.38040000e-05,   2.26810000e-04]),
#   array([  7.30232558e-07,   3.96800000e-06,   1.82560000e-05,
#            6.96960000e-05,   2.18592000e-04,   5.83686000e-04,
#            1.40298600e-03]),
#   array([  2.79215686e-06,   9.01200000e-06,   1.84080000e-05,
#            3.79280000e-05,   7.22160000e-05,   1.26525000e-04])],
#  [array([  1.63600000e-06,   7.49600000e-06,   2.79180000e-05,
#            8.72600000e-05,   2.25282000e-04]),
#   array([  1.66511628e-06,   7.13400000e-06,   2.67820000e-05,
#            8.22780000e-05,   2.16448000e-04,   5.06530000e-04,
#            1.03683200e-03]),
#   array([  5.25490196e-06,   1.41720000e-05,   2.70240000e-05,
#            5.14400000e-05,   8.32600000e-05,   1.37441667e-04])],
#  [array([  1.10800000e-06,   5.64800000e-06,   2.22920000e-05,
#            7.41100000e-05,   2.03734000e-04]),
#   array([  1.12093023e-06,   5.27400000e-06,   2.13340000e-05,
#            7.05200000e-05,   1.96086000e-04,   4.81858000e-04,
#            1.04993400e-03]),
#   array([  3.85098039e-06,   1.09440000e-05,   2.16480000e-05,
#            4.14600000e-05,   7.29440000e-05,   1.19654167e-04])],
#  [array([  4.28000000e-07,   3.60600000e-06,   1.84320000e-05,
#            7.01300000e-05,   2.01714000e-04]),
#   array([  4.41860465e-07,   3.37200000e-06,   1.73100000e-05,
#            6.72440000e-05,   1.93808000e-04,   4.64746000e-04,
#            9.82974000e-04]),
#   array([  2.28235294e-06,   8.00800000e-06,   1.75440000e-05,
#            3.65600000e-05,   6.97320000e-05,   1.19550000e-04])],
#  [array([  3.69400000e-06,   1.49120000e-05,   5.14580000e-05,
#            1.43160000e-04,   3.42622000e-04]),
#   array([  3.76976744e-06,   1.41080000e-05,   4.95780000e-05,
#            1.35738000e-04,   3.33740000e-04,   7.09226000e-04,
#            1.35408800e-03]),
#   array([  1.07450980e-05,   2.76800000e-05,   5.20840000e-05,
#            8.33040000e-05,   1.41620000e-04,   2.18104167e-04])],
#  [array([  1.43000000e-06,   6.05800000e-06,   2.11980000e-05,
#            6.55400000e-05,   1.76430000e-04]),
#   array([  1.47906977e-06,   5.73400000e-06,   2.01920000e-05,
#            6.33180000e-05,   1.69360000e-04,   4.05956000e-04,
#            9.31146000e-04]),
#   array([  4.29019608e-06,   1.10200000e-05,   2.08000000e-05,
#            3.79920000e-05,   6.45680000e-05,   1.05354167e-04])],
#  [array([  1.84800000e-06,   8.09000000e-06,   2.88360000e-05,
#            8.27340000e-05,   2.07764000e-04]),
#   array([  1.91395349e-06,   7.69200000e-06,   2.73000000e-05,
#            7.97120000e-05,   1.98908000e-04,   4.45726000e-04,
#            8.78358000e-04]),
#   array([  5.83333333e-06,   1.48600000e-05,   2.79160000e-05,
#            5.09600000e-05,   8.05280000e-05,   1.29737500e-04])],
#  [array([  3.94000000e-06,   1.24060000e-05,   3.56840000e-05,
#            8.37400000e-05,   1.83328000e-04]),
#   array([  4.03023256e-06,   1.19680000e-05,   3.42640000e-05,
#            8.00480000e-05,   1.79942000e-04,   3.54942000e-04,
#            6.73496000e-04]),
#   array([  9.50392157e-06,   2.05760000e-05,   3.45560000e-05,
#            5.49200000e-05,   8.26240000e-05,   1.26062500e-04])],
#  [array([  7.26000000e-07,   5.79200000e-06,   2.83300000e-05,
#            9.78880000e-05,   2.62094000e-04]),
#   array([  7.58139535e-07,   5.39200000e-06,   2.68260000e-05,
#            9.29340000e-05,   2.51152000e-04,   5.75820000e-04,
#            1.14944200e-03]),
#   array([  3.71764706e-06,   1.25480000e-05,   2.73400000e-05,
#            5.50480000e-05,   9.53120000e-05,   1.60833333e-04])],
#  [array([  2.77400000e-06,   1.11600000e-05,   3.96840000e-05,
#            1.12004000e-04,   2.88572000e-04]),
#   array([  2.86976744e-06,   1.06000000e-05,   3.78020000e-05,
#            1.06996000e-04,   2.74982000e-04,   6.53216000e-04,
#            1.35587200e-03]),
#   array([  8.04901961e-06,   2.05600000e-05,   3.80400000e-05,
#            6.58640000e-05,   1.11764000e-04,   1.78104167e-04])],
#  [array([  1.02000000e-06,   5.66200000e-06,   2.23960000e-05,
#            6.90820000e-05,   1.69026000e-04]),
#   array([  1.06046512e-06,   5.31600000e-06,   2.11780000e-05,
#            6.69720000e-05,   1.65706000e-04,   3.47614000e-04,
#            6.69208000e-04]),
#   array([  3.82549020e-06,   1.11800000e-05,   2.16480000e-05,
#            4.00760000e-05,   6.85400000e-05,   1.08112500e-04])],
#  [array([  1.93000000e-06,   9.30000000e-06,   3.51380000e-05,
#            1.01486000e-04,   2.46726000e-04]),
#   array([  2.01627907e-06,   8.79400000e-06,   3.33500000e-05,
#            9.73200000e-05,   2.41452000e-04,   5.11908000e-04,
#            1.03677000e-03]),
#   array([  6.53333333e-06,   1.76200000e-05,   3.39840000e-05,
#            6.02760000e-05,   9.85680000e-05,   1.58645833e-04])],
#  [array([  7.32000000e-07,   4.08600000e-06,   1.81860000e-05,
#            6.86060000e-05,   2.19534000e-04]),
#   array([  7.58139535e-07,   3.84800000e-06,   1.71840000e-05,
#            6.56600000e-05,   2.06902000e-04,   5.82134000e-04,
#            1.42141600e-03]),
#   array([  2.74313725e-06,   8.54800000e-06,   1.72320000e-05,
#            3.54320000e-05,   6.80600000e-05,   1.18095833e-04])],
#  [array([  1.23000000e-06,   5.57600000e-06,   2.07580000e-05,
#            6.58000000e-05,   1.81044000e-04]),
#   array([  1.26511628e-06,   5.20600000e-06,   1.96800000e-05,
#            6.37900000e-05,   1.73674000e-04,   4.15098000e-04,
#            9.60984000e-04]),
#   array([  3.86666667e-06,   1.05280000e-05,   2.00640000e-05,
#            3.73280000e-05,   6.52520000e-05,   1.07916667e-04])],
#  [array([  8.32000000e-07,   5.06800000e-06,   2.29880000e-05,
#            8.43240000e-05,   2.52594000e-04]),
#   array([  8.55813953e-07,   4.72600000e-06,   2.17840000e-05,
#            8.01740000e-05,   2.42358000e-04,   6.23758000e-04,
#            1.46906600e-03]),
#   array([  3.36470588e-06,   1.06120000e-05,   2.21360000e-05,
#            4.42640000e-05,   8.18720000e-05,   1.42137500e-04])],
#  [array([  5.72000000e-07,   4.23000000e-06,   2.15120000e-05,
#            8.34300000e-05,   2.50890000e-04]),
#   array([  5.72093023e-07,   3.95600000e-06,   2.02880000e-05,
#            7.95880000e-05,   2.40150000e-04,   6.08302000e-04,
#            1.34506600e-03]),
#   array([  2.69411765e-06,   9.48000000e-06,   2.01680000e-05,
#            4.30200000e-05,   8.04920000e-05,   1.42704167e-04])],
#  [array([  2.21800000e-06,   1.07360000e-05,   4.05320000e-05,
#            1.14450000e-04,   2.72440000e-04]),
#   array([  2.26511628e-06,   1.01640000e-05,   3.87460000e-05,
#            1.09242000e-04,   2.66406000e-04,   5.46740000e-04,
#            1.06854600e-03]),
#   array([  7.52941176e-06,   2.01520000e-05,   3.96000000e-05,
#            6.84960000e-05,   1.13244000e-04,   1.75125000e-04])],
#  [array([  2.01800000e-06,   9.08200000e-06,   3.35800000e-05,
#            9.81440000e-05,   2.45688000e-04]),
#   array([  2.05348837e-06,   8.55000000e-06,   3.16680000e-05,
#            9.46560000e-05,   2.34158000e-04,   5.23670000e-04,
#            9.82860000e-04]),
#   array([  6.45098039e-06,   1.68800000e-05,   3.27280000e-05,
#            5.79200000e-05,   9.58040000e-05,   1.56491667e-04])],
#  [array([  2.15000000e-06,   8.89600000e-06,   3.09740000e-05,
#            8.75460000e-05,   2.19892000e-04]),
#   array([  2.18139535e-06,   8.44200000e-06,   2.95560000e-05,
#            8.42060000e-05,   2.09826000e-04,   4.73614000e-04,
#            9.21854000e-04]),
#   array([  6.44509804e-06,   1.62120000e-05,   3.02600000e-05,
#            5.38480000e-05,   8.58360000e-05,   1.35266667e-04])],
#  [array([  1.64800000e-06,   7.53200000e-06,   2.70640000e-05,
#            7.91180000e-05,   1.91436000e-04]),
#   array([  1.67209302e-06,   7.16400000e-06,   2.59860000e-05,
#            7.60420000e-05,   1.83418000e-04,   3.97320000e-04,
#            7.87592000e-04]),
#   array([  5.29411765e-06,   1.41080000e-05,   2.62400000e-05,
#            4.90080000e-05,   7.58640000e-05,   1.22866667e-04])],
#  [array([  1.46000000e-06,   7.30600000e-06,   2.87020000e-05,
#            9.08980000e-05,   2.42698000e-04]),
#   array([  1.52093023e-06,   6.90400000e-06,   2.72420000e-05,
#            8.75480000e-05,   2.31994000e-04,   5.58052000e-04,
#            1.18899600e-03]),
#   array([  5.00392157e-06,   1.43040000e-05,   2.78080000e-05,
#            5.32560000e-05,   8.70600000e-05,   1.47750000e-04])],
#  [array([  3.90000000e-07,   3.20600000e-06,   1.49120000e-05,
#            5.54180000e-05,   1.63132000e-04]),
#   array([  4.02325581e-07,   2.97600000e-06,   1.42180000e-05,
#            5.32960000e-05,   1.54314000e-04,   3.93716000e-04,
#            8.97240000e-04]),
#   array([  2.02745098e-06,   6.91600000e-06,   1.45840000e-05,
#            2.86160000e-05,   5.55200000e-05,   9.20541667e-05])],
#  [array([  9.10000000e-07,   4.35400000e-06,   1.72460000e-05,
#            5.92500000e-05,   1.71412000e-04]),
#   array([  9.39534884e-07,   4.10200000e-06,   1.64440000e-05,
#            5.66660000e-05,   1.65242000e-04,   4.22746000e-04,
#            9.73578000e-04]),
#   array([  3.02549020e-06,   8.59600000e-06,   1.66480000e-05,
#            3.21920000e-05,   5.88880000e-05,   9.73583333e-05])],
#  [array([  4.47800000e-06,   1.73880000e-05,   5.82160000e-05,
#            1.59010000e-04,   3.89864000e-04]),
#   array([  4.55116279e-06,   1.65840000e-05,   5.56580000e-05,
#            1.53576000e-04,   3.76806000e-04,   8.34936000e-04,
#            1.72681400e-03]),
#   array([  1.25862745e-05,   3.22920000e-05,   5.72400000e-05,
#            9.45800000e-05,   1.57196000e-04,   2.49600000e-04])],
#  [array([  5.42000000e-07,   3.89800000e-06,   1.84540000e-05,
#            6.79140000e-05,   1.87564000e-04]),
#   array([  5.53488372e-07,   3.64200000e-06,   1.74740000e-05,
#            6.49720000e-05,   1.80668000e-04,   4.24380000e-04,
#            9.05646000e-04]),
#   array([  2.50784314e-06,   8.50800000e-06,   1.77320000e-05,
#            3.57680000e-05,   6.68640000e-05,   1.10908333e-04])],
#  [array([  2.53200000e-06,   1.12380000e-05,   4.17980000e-05,
#            1.18436000e-04,   2.95628000e-04]),
#   array([  2.58837209e-06,   1.06780000e-05,   3.98940000e-05,
#            1.14890000e-04,   2.86584000e-04,   6.32000000e-04,
#            1.21108000e-03]),
#   array([  7.94901961e-06,   2.14280000e-05,   4.06120000e-05,
#            7.00080000e-05,   1.19188000e-04,   1.86612500e-04])],
#  [array([  1.84600000e-06,   8.12600000e-06,   3.10280000e-05,
#            9.86400000e-05,   2.73470000e-04]),
#   array([  1.90000000e-06,   7.71800000e-06,   2.93180000e-05,
#            9.36720000e-05,   2.62094000e-04,   6.67992000e-04,
#            1.53782800e-03]),
#   array([  5.81764706e-06,   1.52200000e-05,   3.01560000e-05,
#            5.57600000e-05,   9.49440000e-05,   1.60975000e-04])],
#  [array([  4.19600000e-06,   1.51580000e-05,   4.62800000e-05,
#            1.15962000e-04,   2.50920000e-04]),
#   array([  4.31627907e-06,   1.43000000e-05,   4.47020000e-05,
#            1.10438000e-04,   2.45648000e-04,   4.93186000e-04,
#            9.12862000e-04]),
#   array([  1.11470588e-05,   2.63520000e-05,   4.69280000e-05,
#            7.16440000e-05,   1.14800000e-04,   1.73404167e-04])],
#  [array([  1.97600000e-06,   8.55000000e-06,   3.11920000e-05,
#            9.20560000e-05,   2.31754000e-04]),
#   array([  2.01162791e-06,   8.09200000e-06,   2.94620000e-05,
#            8.88140000e-05,   2.26682000e-04,   5.03200000e-04,
#            1.07325600e-03]),
#   array([  6.11176471e-06,   1.57440000e-05,   3.02720000e-05,
#            5.52480000e-05,   8.97800000e-05,   1.43845833e-04])],
#  [array([  8.68000000e-07,   5.95800000e-06,   2.58200000e-05,
#            7.94300000e-05,   1.86362000e-04]),
#   array([  9.02325581e-07,   5.52200000e-06,   2.43980000e-05,
#            7.56820000e-05,   1.83696000e-04,   3.63684000e-04,
#            6.85826000e-04]),
#   array([  3.89215686e-06,   1.22240000e-05,   2.47560000e-05,
#            4.74400000e-05,   7.67040000e-05,   1.21183333e-04])],
#  [array([  8.96000000e-07,   5.40200000e-06,   2.41700000e-05,
#            8.27420000e-05,   2.26084000e-04]),
#   array([  9.37209302e-07,   5.07000000e-06,   2.25720000e-05,
#            7.89580000e-05,   2.17564000e-04,   4.99268000e-04,
#            1.05343200e-03]),
#   array([  3.58235294e-06,   1.11720000e-05,   2.28800000e-05,
#            4.60120000e-05,   7.99320000e-05,   1.36741667e-04])],
#  [array([  3.94200000e-06,   1.37640000e-05,   4.36000000e-05,
#            1.14074000e-04,   2.71130000e-04]),
#   array([  4.04186047e-06,   1.31000000e-05,   4.20040000e-05,
#            1.10404000e-04,   2.63304000e-04,   5.83090000e-04,
#            1.14802000e-03]),
#   array([  1.02647059e-05,   2.40640000e-05,   4.37240000e-05,
#            6.94960000e-05,   1.11840000e-04,   1.74595833e-04])],
#  [array([  2.92000000e-06,   1.16120000e-05,   4.08380000e-05,
#            1.14290000e-04,   2.92112000e-04]),
#   array([  2.96046512e-06,   1.09560000e-05,   3.90640000e-05,
#            1.11098000e-04,   2.76232000e-04,   6.46144000e-04,
#            1.28197200e-03]),
#   array([  8.38823529e-06,   2.12640000e-05,   3.96800000e-05,
#            6.78640000e-05,   1.11996000e-04,   1.83708333e-04])],
#  [array([  1.45800000e-06,   6.07400000e-06,   2.11400000e-05,
#            6.55400000e-05,   1.72782000e-04]),
#   array([  1.50697674e-06,   5.75200000e-06,   2.01340000e-05,
#            6.24560000e-05,   1.66744000e-04,   4.09434000e-04,
#            8.89850000e-04]),
#   array([  4.32941176e-06,   1.10200000e-05,   2.06440000e-05,
#            3.73720000e-05,   6.39520000e-05,   1.03737500e-04])],
#  [array([  2.27200000e-06,   9.48000000e-06,   3.28880000e-05,
#            9.05800000e-05,   2.19612000e-04]),
#   array([  2.32093023e-06,   8.96600000e-06,   3.13200000e-05,
#            8.72000000e-05,   2.09400000e-04,   4.68650000e-04,
#            9.21854000e-04]),
#   array([  6.86078431e-06,   1.70800000e-05,   3.22440000e-05,
#            5.59160000e-05,   8.81720000e-05,   1.39420833e-04])],
#  [array([  1.75600000e-06,   8.47400000e-06,   3.33680000e-05,
#            9.93160000e-05,   2.39826000e-04]),
#   array([  1.81395349e-06,   8.04400000e-06,   3.14140000e-05,
#            9.57300000e-05,   2.34158000e-04,   4.69698000e-04,
#            8.42836000e-04]),
#   array([  5.96470588e-06,   1.61560000e-05,   3.26480000e-05,
#            5.91680000e-05,   9.69200000e-05,   1.56491667e-04])],
#  [array([  1.53200000e-06,   7.39800000e-06,   2.76220000e-05,
#            8.50960000e-05,   2.17536000e-04]),
#   array([  1.58139535e-06,   6.95400000e-06,   2.66060000e-05,
#            8.15780000e-05,   2.08318000e-04,   4.82952000e-04,
#            1.01811600e-03]),
#   array([  5.12941176e-06,   1.40480000e-05,   2.68360000e-05,
#            5.06120000e-05,   8.11920000e-05,   1.33637500e-04])],
#  [array([  2.17800000e-06,   1.05580000e-05,   3.94340000e-05,
#            1.10006000e-04,   2.64418000e-04]),
#   array([  2.22558140e-06,   9.93200000e-06,   3.78040000e-05,
#            1.05060000e-04,   2.58396000e-04,   5.39368000e-04,
#            1.03337800e-03]),
#   array([  7.37058824e-06,   1.97680000e-05,   3.81040000e-05,
#            6.69160000e-05,   1.08856000e-04,   1.67566667e-04])]]

# %%
histo2=np.array(histo1)

# %%
histo2[0][0]
# Out:
# array([  2.18600000e-06,   9.37400000e-06,   3.30800000e-05,
#          9.49600000e-05,   2.31248000e-04])

# %%
figure(figsize(9,7))
plot()
ylabel(r"$\Phi(M_{1350})$ $($ Mpc$^{-3}$mag$^{-1})$",fontsize=20)
xlabel('$M_{1350}$',fontsize=20)
errorbar(Obs_data2[:,0],Obs_data2[:,1], xerr=Obs_data2xerror, yerr=Obs_data2yerror, fmt='ko', label="Bouwens et al 2014")
errorbar(Obs_data1[:,0],Obs_data1[:,1], xerr=0.25, yerr=Obs_data1yerror, fmt='ro', label="Willott et al 2013")
errorbar(Obs_data3[:,0],Obs_data3[:,1], xerr=Obs_data3xerror, yerr=Obs_data3yerror, fmt='bo', label="McLure et al 2009")

plt.grid(True)
title("Observed Luminosity Functions",fontsize=20)
yscale("log")
legend(loc=0)
plt.axis([-23,-16,10**-8,0.01])
# Out:
# [-23, -16, 1e-08, 0.01]

# %%
figure(figsize(9,7))
plot()
ylabel(r"$\Phi(M_{1350})($ Mpc$^{-3}$mag$^{-1})$",fontsize=20)
xlabel('$M_{1350}$',fontsize=20)
plt.grid(True)
title("Cosmic Variance",fontsize=25)
tick_params(axis="both", labelsize=15)


for K in range (64):
    scatter( Obs_data1[:,0] , histo2[K][0],s=10, color="red")
    scatter( Obs_data2[:,0] , histo2[K][1],s=10, color="black")
    scatter( Obs_data3[:,0] , histo2[K][2],s=10, color="blue")

errorbar(Obs_data2[:,0],Obs_data2[:,1], xerr=Obs_data2xerror, yerr=Obs_data2yerror, fmt='.', color="0.40", label="Bouwens et al 2014")
errorbar(Obs_data1[:,0],Obs_data1[:,1], xerr=0.25, yerr=Obs_data1yerror, fmt='.', color="0.40", label="Willott et al 2013")
errorbar(Obs_data3[:,0],Obs_data3[:,1], xerr=Obs_data3xerror, yerr=Obs_data3yerror, fmt='.', color="0.40", label="McLure et al 2009")


plt.axis([-23,-18,10**-9,0.01])
yscale("log")
savefig("cosmic_variance.pdf")

# %%
figure(figsize(9,7))
plot()
ylabel(r"$\Phi(M_{1350})$ $($ Mpc$^{-3}$mag$^{-1})$",fontsize=20)
xlabel('$M_{1350}$',fontsize=20)
plt.grid(True)
title("Cosmic Variance",fontsize=20)
tick_params(axis="both", labelsize=15)

for K in range (64):
    plot( Obs_data1[:,0] , histo2[K][0], "r-")
    plot( Obs_data2[:,0] , histo2[K][1], "k-")
    plot( Obs_data3[:,0] , histo2[K][2], "b-")

errorbar(Obs_data2[:,0],Obs_data2[:,1], xerr=Obs_data2xerror, yerr=Obs_data2yerror, fmt='.', color="0.40", label="Bouwens et al 2014")
errorbar(Obs_data1[:,0],Obs_data1[:,1], xerr=0.25, yerr=Obs_data1yerror, fmt='.', color="0.40", label="Willott et al 2013")
errorbar(Obs_data3[:,0],Obs_data3[:,1], xerr=Obs_data3xerror, yerr=Obs_data3yerror, fmt='.', color="0.40", label="McLure et al 2009")


plt.axis([-23,-19,10**-9,0.01])
yscale("log")
