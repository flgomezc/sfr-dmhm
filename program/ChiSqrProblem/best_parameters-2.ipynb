# %%
# Last modification: 2015-mar-24 West Lafayette
# %pylab inline
from random import *
from observational_data import *
from constants import *
from functions import *
# Out:
# Populating the interactive namespace from numpy and matplotlib
# observational_data.py:64: RuntimeWarning: divide by zero encountered in divide
#   Obs_data2_log10yerror = [array(log10(Bouwens[:,1]/(Bouwens[:,1]-Bouwens[:,2]))),

# %%
##################  Name of the Observed Dataset
name = ""

# %%
# This cell operates over one specific box.
BoxNum=2
# Open the raw data from Markov Chain-MoteCarlo
# L_0 	 M_0 	 beta 	 gamma 	 chi_sqr 	 Number of Bins
if (Dust_Ext == 1): MCMC_raw = np.loadtxt('results_w_ext'+name+'/'+str(BoxNum)+'.dat',usecols=(0,1,2,3,4,5),skiprows=0); 
else:
    MCMC_raw = np.loadtxt('results_wo_ext'+name+'/'+str(BoxNum)+'.dat',usecols=(0,1,2,3,4,5),skiprows=0); 
BoxLength = 250.0 # Mpc h^{-1}

LABELS = ["$\log_{10}(L_0)$", "$\log_{10}(M_0)$", r"$\beta$", r"$\gamma$"]


index = where( MCMC_raw[:,4] == MCMC_raw[:,4].min() )[0] 
L_min     = MCMC_raw[index,0][0]
M_min     = MCMC_raw[index,1][0]
beta_min  = MCMC_raw[index,2][0]
gamma_min = MCMC_raw[index,3][0]
chi_sqr_min= MCMC_raw[index,4][0]
bins      = MCMC_raw[index,5][0]

MINS = [L_min, M_min, beta_min, gamma_min]

for k in range(4):
    print LABELS[k], '\t', MINS[k]
print  chi_sqr_min, bins, "Index min= ", index

histo_0 = histogram(MCMC_raw[:,0], bins=30)
histo_1 = histogram(MCMC_raw[:,1], bins=30)
histo_2 = histogram(MCMC_raw[:,2], bins=30)
histo_3 = histogram(MCMC_raw[:,3], bins=30)

#################### Chi2 vs MCMC steps  ###################################    
#
fig = figure(figsize(10,5))
plot(MCMC_raw[:,4])
axhline(y=chi_sqr_min, color='red')
axvline(x=1.0*index[0], color='red')
ylabel(r"$\chi^2$ ",fontsize=20)
xlabel('MCMC steps')
#ylim([0.01,1])
#savefig('11000 MCMC steps.pdf')
yscale('log')

fig = figure(figsize(10,5))
hist(log10(MCMC_raw[:,4]))
#axhline(y=chi_sqr_min, color='red')
#axvline(x=1.0*index[0], color='red')
xlabel(r"$\log_{10}(\chi^2)$ ",fontsize=20)
ylabel('Freq')
#xlabel('MCMC steps')
#ylim([0.01,1])
#savefig('11000 MCMC steps.pdf')
yscale('log')
#######################  end of Chi2 plot ########
# Out:
# $\log_{10}(L_0)$ 	17.6705150385
# $\log_{10}(M_0)$ 	10.2103015963
# $\beta$ 	1.07787987093
# $\gamma$ 	0.534231104972
# -0.0 0.0005 Index min=  [ 3249  3250  3251 ..., 19996 19997 19998]
# -c:45: RuntimeWarning: divide by zero encountered in log10
# /Users/flgomezc/anaconda/lib/python2.7/site-packages/numpy/core/function_base.py:97: RuntimeWarning: invalid value encountered in multiply
#   y = _nx.arange(0, num, dtype=dtype) * step + start
# /Users/flgomezc/anaconda/lib/python2.7/site-packages/numpy/core/function_base.py:97: RuntimeWarning: invalid value encountered in add
#   y = _nx.arange(0, num, dtype=dtype) * step + start
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-33e183136115> in <module>()
#      51 #ylim([0.01,1])
#      52 #savefig('11000 MCMC steps.pdf')
# ---> 53 yscale('log')
#      54 #######################  end of Chi2 plot ########
#      55
#
# /Users/flgomezc/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.pyc in yscale(*args, **kwargs)
#    1553     """
#    1554     ax = gca()
# -> 1555     ax.set_yscale(*args, **kwargs)
#    1556     draw_if_interactive()
#    1557
#
# /Users/flgomezc/anaconda/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in set_yscale(self, value, **kwargs)
#    2835             kwargs['nonposy'] = 'clip'
#    2836         self.yaxis._set_scale(value, **kwargs)
# -> 2837         self.autoscale_view(scalex=False)
#    2838         self._update_transScale()
#    2839
#
# /Users/flgomezc/anaconda/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in autoscale_view(self, tight, scalex, scaley)
#    1964                 y1 += delta
#    1965             if not _tight:
# -> 1966                 y0, y1 = ylocator.view_limits(y0, y1)
#    1967             self.set_ybound(y0, y1)
#    1968
#
# /Users/flgomezc/anaconda/lib/python2.7/site-packages/matplotlib/ticker.pyc in view_limits(self, vmin, vmax)
#    1523         if minpos <= 0 or not np.isfinite(minpos):
#    1524             raise ValueError(
# -> 1525                 "Data has no positive values, and therefore can not be "
#    1526                 "log-scaled.")
#    1527
#
# ValueError: Data has no positive values, and therefore can not be log-scaled.
# /Users/flgomezc/anaconda/lib/python2.7/site-packages/IPython/core/formatters.py:239: FormatterWarning: Exception in image/png formatter: Data has no positive values, and therefore can not be log-scaled.
#   FormatterWarning,

# %% [markdown]
# # ERROR :
# $\chi^2 < 0$ ! ! !

# %%
############## MCMC walking steps plots ########################
#               y axis = Parameters
#               x axis = MCMC step
fig = figure(figsize=(10, 5))
fig.subplots_adjust(hspace=0.20, wspace=0.2,top=1.5, right=1.0, bottom=0.0)
ax1=fig.add_subplot(221); ax2=fig.add_subplot(222); ax3=fig.add_subplot(223); ax4=fig.add_subplot(224);
ax = [ax1,ax2,ax3,ax4]
for k in range(4):
    ax[k].plot(MCMC_raw[:,k])
    ax[k].set_xlabel(LABELS[k], fontsize=20)
    ax[k].axhline(y=MINS[k], color='red')
    ax[k].axvline(x=1.0*index[0], color='red')
################################### end of MCMC walking steps

# %%
############## Scattering plots ########################
#               y axis = chi2 
#               x axis = Parameters
fig = figure(figsize=(10, 5))
fig.subplots_adjust(hspace=0.20, wspace=0.0,top=1.5, right=1.0, bottom=0.0)
ax1=fig.add_subplot(221); ax2=fig.add_subplot(222); ax3=fig.add_subplot(223); ax4=fig.add_subplot(224);
ax = [ax1,ax2,ax3,ax4]
for k in range(4):
    ax[k].scatter(MCMC_raw[:,k], MCMC_raw[:,4], s=0.01)
    ax[k].set_xlabel(LABELS[k], fontsize=20)
    ax[k].axvline(x=MINS[k], color='red')
    ax[k].set_yscale('log')
    
ax1.set_ylabel(" $\chi^2$ ",fontsize=20)
ax2.yaxis.set_major_formatter(plt.NullFormatter())
ax3.set_ylabel(" $\chi^2$ ",fontsize=20)
ax4.yaxis.set_major_formatter(plt.NullFormatter())
####################### end of scattering plots ########

# %%
################## Histograms #############################
#               y axis = freq 
#               x axis = Parameters
fig = figure(figsize=(10, 5))
fig.subplots_adjust(hspace=0.20, wspace=0.15,top=1.5, right=1.0, bottom=0.0)
ax1=fig.add_subplot(221); ax2=fig.add_subplot(222); ax3=fig.add_subplot(223); ax4=fig.add_subplot(224)
ax = [ax1,ax2,ax3,ax4]
for k in range(4):
    ax[k].hist(MCMC_raw[:,k], bins=30)
    ax[k].axvline(x=MINS[k], color='red')
    ax[k].set_xlabel(LABELS[k], fontsize=20)
################################## end of Histograms #####
