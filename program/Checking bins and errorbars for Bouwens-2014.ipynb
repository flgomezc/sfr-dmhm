# %%
import matplotlib
matplotlib.use('Agg') #Anti Grain-Geometry: Used to convert to EPS
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
HIST2_bins=[-22.7,-22.27,-21.77,-21.27,-20.77,-20,27,-19,77,-19.27,-18.27,-17.27,-16,27]

Bouwens = np.array( 
[# Mag,LumFunct, +/err #
[-22.52,0.000002,0.000002],
[-22.02,0.000011,0.000004],
[-21.52,0.000029,0.000008],
[-21.02,0.000060,0.000012],
[-20.52,0.000146,0.000023],
[-20.02,0.000296,0.000045],
[-19.52,0.000611,0.000081],
[-18.77,0.000860,0.000150],
[-17.77,0.002920,0.000650],
[-16.77,0.004710,0.001490]
])  

Obs_data2 = np.zeros([10,4])
Obs_data2_log10 = np.zeros([10,4])

Obs_data2yerror = [array(Bouwens[:,2]),array(Bouwens[:,2])]
Obs_data2xerror = [0.25,0.25,0.25,0.25,0.25,0.25,0.25,0.5,0.5,0.5]
Obs_data2[:,0]=Bouwens[:,0]
Obs_data2[:,1]=Bouwens[:,1]
Obs_data2[:,2]=0
Obs_data2[:,3]=0.25
Obs_data2_log10[:,0]=Bouwens[:,0]
Obs_data2_log10[:,1]=log10(Bouwens[:,1])
Obs_data2_log10[:,2]=0
Obs_data2_log10[:,3]=0.25
Obs_data2yerror[0][0]=0.00000199

Obs_data2_log10yerror = [array(log10(Bouwens[:,1]/(Bouwens[:,1]-Bouwens[:,2]))),
                         array(log10((Bouwens[:,1]+Bouwens[:,2])/Bouwens[:,1]))]

#Obs_data3_log10yerror = [array(log10(McLure[:,1]/McLure[:,2])),array(log10(McLure[:,3]/McLure[:,1]))]
# McLure1 = Observed value
# McLure2 = Low error value
# McLure3 = Up errorbar value

# %% [markdown]
# http://matplotlib.org/1.3.1/examples/statistics/errorbar_demo_features.html
#
# Errorbars with Asymmetric error.
#
# Bouwens 2014, sec 4.1 ec 1

# %%
figure(figsize(9,7))
plot()
ylabel(r"$\Phi(M_{1350})$ $($ Mpc$^{-3}$mag$^{-1})$",fontsize=20)
xlabel('$M_{1350}$',fontsize=20)
errorbar(Obs_data2[:,0],Obs_data2[:,1], xerr=Obs_data2xerror, yerr=Obs_data2yerror, fmt='ko')
plt.grid(True)
title("Observational data from Bouwens et al-2014",fontsize=20)
yscale("log")
plt.axis([-23,-16,10**-6,0.01])
# Out:
# [-23, -16, 1e-06, 0.01]

# %%
Obs_data2_log10yerror[0][0]=1.0

# %%
Obs_data2_log10yerror
# Out:
# [array([ 1.        ,  0.19629465,  0.1401787 ,  0.09691001,  0.07444774,
#          0.07161799,  0.06176534,  0.0832401 ,  0.10935699,  0.16516504]),
#  array([ 0.30103   ,  0.13469857,  0.10580373,  0.07918125,  0.06353385,
#          0.06146267,  0.05406488,  0.06982292,  0.08728536,  0.11937078])]

# %%
figure(figsize(9,7))
plot()
ylabel(r"$\Phi(M_{1350})$ $($ Mpc$^{-3}$mag$^{-1})$",fontsize=20)
xlabel('$M_{1350}$',fontsize=20)
errorbar(Obs_data2_log10[:,0],Obs_data2_log10[:,1], xerr=Obs_data2xerror, yerr=Obs_data2_log10yerror, fmt='ko')
plt.grid(True)
title("Observational data from Bouwens et al-2014",fontsize=20)
#yscale("log")
#plt.axis([-23,-16,10**-6,0.01])

# %%
sigma2 = (Obs_data2_log10yerror[:][0] + Obs_data2_log10yerror[:][1] )/2

# %%
sigma2
# Out:
# array([ 0.650515  ,  0.16549661,  0.12299121,  0.08804563,  0.0689908 ,
#         0.06654033,  0.05791511,  0.07653151,  0.09832118,  0.14226791])

# %%
Obs_data2_log10yerror
# Out:
# [array([ 1.        ,  0.19629465,  0.1401787 ,  0.09691001,  0.07444774,
#          0.07161799,  0.06176534,  0.0832401 ,  0.10935699,  0.16516504]),
#  array([ 0.30103   ,  0.13469857,  0.10580373,  0.07918125,  0.06353385,
#          0.06146267,  0.05406488,  0.06982292,  0.08728536,  0.11937078])]

# %%
sigma2[4]
# Out:
# 0.068990796587137762
