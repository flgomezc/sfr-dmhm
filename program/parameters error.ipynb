# %%
# Last modification: 2015-mar-03 West Lafayette
# %pylab inline
from random import *
from observational_data import *
from constants import *
from functions import *
# Out:
# Populating the interactive namespace from numpy and matplotlib
# observational_data.py:58: RuntimeWarning: divide by zero encountered in divide
#   Obs_data2_log10yerror = [array(log10(Bouwens[:,1]/(Bouwens[:,1]-Bouwens[:,2]))),

# %%
##################  Name of the Observed Dataset
name = "OD3"

# %% [markdown]
# #Calculate parameter error in box #15
# 03-mar-2015

# %%
A = range(0,64)  #range(0,64)
#output = [open( '../results/%i.dat' %filenumber, 'w') for filenumber in A]

Dust_Extinction()

#if (Dust_Ext == 1): BestPar  = open( 'analysis/best_parameters_w_ext '+name+'.dat', 'w')
#else:               BestPar  = open( 'analysis/best_parameters_wo_ext '+name+'.dat', 'w')

Param_list = ['L_0','M_0','alpha','gamma']
Param_labels = [r'$\log_{10}(L_0)$', r'$\log_{10}(M_0)$', r'$\alpha$', r'$\gamma$']


for DATA in A:
    if (Dust_Ext == 1): STR = 'results_w_ext '+name+'/'+str(DATA)+'.dat'
    else:               STR = 'results_wo_ext '+name+'/'+str(DATA)+'.dat'
        
    MCMC_raw = np.loadtxt(STR,usecols=(0,1,2,3,4,5), skiprows=0); 
    BoxLength = 250.0 # Mpc h^{-1}


    histo  = []
    Par_min = []
    index_min = where( MCMC_raw[:,4] == MCMC_raw[:,4].min() )[0] 
    for k in range(4):
        histo.append(histogram(MCMC_raw[:,k], bins=30))
        Par_min.append(MCMC_raw[index_min,k][0])
    
    
    fig = figure(figsize=(15, 12))

    fig.subplots_adjust(hspace=0.20, wspace=0.10,top=0.9, right=1.0, bottom=0.0)

    ax1 = fig.add_subplot(221)
    ax2 = fig.add_subplot(222)
    ax3 = fig.add_subplot(223)
    ax4 = fig.add_subplot(224)
        
    ax = [ax1, ax2, ax3, ax4]
    
    for k in range(4): 
####### Here we get the 0.6827 covered region
        F_Lmax = histo[k][0].max()
        N = 1.0*MCMC_raw[:,0].size
        over = np.zeros(histo[k][0].size)
        F63=0
        F63_min = 0
        F63_max = 0
        
        for i in range(F_Lmax):
            for j in range(over.size):
                if histo[k][0][j]==F_Lmax-i :
                    over[j]=1

            covered_area = 0.0
            for j in range(over.size):
                covered_area += (histo[k][0][j]-F_Lmax+i)*over[j]/N

            if covered_area >= 0.6827 :
                F63 = F_Lmax - i
                for j in range(over.size):
                    if over[j]==1:
                        F63_min = histo[k][1][j]
                        break
                for j in range(over.size):
                    if over[over.size-j-1]==1:
                        F63_max = histo[k][1][over.size-j]
                        break
                break
        print Param_list[k], F63_min, Par_min[k], F63_max, F63
        
######## PLotting        
        ax[k].hist(MCMC_raw[:,k],bins=30)
        ax[k].axvline(x=Par_min[k])
        ax[k].axvline(x=average(MCMC_raw[:,k]), color="red")
        ax[k].set_xlabel(str(Param_labels[k]),fontsize=20)   
        
        ax[k].axhline(y=F_Lmax-i, color="k")         
        ax[k].axvline(x=F63_min, linestyle='--')
        ax[k].axvline(x=F63_max, linestyle='--')
        
if (Dust_Ext == 1):
    fig.suptitle("Parameter Dispersion for box #15\n"+str(name)+" with Dust Attenuation", fontsize=24)
    savefig('analysis/onebox_param_disp_w '+name+'.png')
else:
    fig.suptitle("Parameter Dispersion for box #15\n"+str(name)+" without Dust Attenuation", fontsize=24)    
    savefig('analysis/onebox_param_disp_wo '+name+'.png')  
    
    
############################

###########################

if (Dust_Ext == 1): Param_Scat = np.loadtxt('analysis/best_parameters_w_ext '+name+'.dat',usecols=(0,1,2,3), skiprows=0);
else:               Param_Scat = np.loadtxt('analysis/best_parameters_wo_ext '+name+'.dat',usecols=(0,1,2,3), skiprows=0); 
Dust_Extinction()

if (Dust_Ext == 1): data  = open( 'analysis/scat_best_parameters_w_ext '+name+'.dat', 'w')
else:               data  = open( 'analysis/scat_best_parameters_wo_ext '+name+'.dat', 'w')
data.write('Param \t F68min \t Mean \t F68max \n F68 \n')    
    
fig = figure(figsize=(10, 9))
#fig.suptitle("Cosmic Variance", fontsize=30)
#text(.5,0.9,'Cosmic Variance', fontsize=30, horizontalalignment='center')

########################################################################## CHANGE FILENAME HERE !!!
fig.suptitle('Best parameters for '+name+' over 64 boxes.', fontsize=18)
#fig.subplots_adjust(hspace=0.20, wspace=0.20,top=1.5, right=1.0, bottom=0.0)
fig.subplots_adjust(hspace=0.25, wspace=0.20,top=0.91, right=0.95, bottom=0.08, left=0.07)

ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
ax3 = fig.add_subplot(223)
ax4 = fig.add_subplot(224)

ax=[ax1,ax2,ax3,ax4]

histo=[]

for k in range(4):

    histo.append(histogram(Param_Scat[:,k]))
    N = 1.0*Param_Scat[:,0].size


####### Here we get the 0.6827 covered region
    F_Lmax = histo[k][0].max()
    over = np.zeros(histo[k][0].size)
    F63=0
    F63_min = 0
    F63_max = 0
    for i in range(F_Lmax):
        for j in range(over.size):
            if histo[k][0][j]==F_Lmax-i :
                over[j]=1

        covered_area = 0.0
        for j in range(over.size):
            covered_area += (histo[k][0][j]-F_Lmax+i)*over[j]/N
            
        if covered_area >= 0.6827 :
            F63 = F_Lmax - i
            for j in range(over.size):
                if over[j]==1:
                    F63_min = histo[k][1][j]
                    break
            for j in range(over.size):
                if over[over.size-j-1]==1:
                    F63_max = histo[k][1][over.size-j]
                    break
            break
    data.write( str(Param_list[k])+'\t'+str(F63_min)+'\t'+str(Par_min[k])+'\t'+str(F63_max)+'\t'+str(F63)+'\n')


    ax[k].hist(Param_Scat[:,k])
    ax[k].set_xlabel(str(Param_labels[k]),fontsize=20)
    ax[k].axhline(y=F_Lmax-i, color="k")         
    ax[k].axvline(x=F63_min, linestyle='--')
    ax[k].axvline(x=F63_max, linestyle='--')

########################################################################## CHANGE FILENAME HERE !!!
if (Dust_Ext == 1):
    savefig('analysis/bestpar_disp_w '+name+'.png')
else:
    savefig('analysis/bestpar_disp_wo '+name+'.png')    
    
data.close()
# Out:
# Dust Extinction ON
# L_0
#  17.9814409761 18.0166842479 18.0983854235 166
# M_0
#  10.8932211059 11.154565189 11.3542069717 120
# alpha
# M_0
#  10.6095879324 10.6583607686 11.2427089536 126
# alpha
#  0.624865994403 1.08875809621 1.11184784159 121
# gamma
#  0.0814994682095 0.107317771726 0.275266898851 153
# L_0
#  17.9806191409 18.0265932932 18.0438044711 209
# M_0
#  11.0424029433 11.111077135 11.3606462301 136
# alpha
#  0.454865492924 0.473425108884 0.819835917459 125
# gamma
#  0.221420065792 0.254849288759 0.343121129715 216
# L_0
#  17.9457225856 18.0549189139 18.0602734293 152
# M_0
#  10.8488879954 11.1393615224 11.2059650026 140
# alpha
#  0.13301163169 0.13301163169 0.871757513416 119
# gamma
#  0.108882214833 0.115734421991 0.234765588616 164
# L_0
#  17.9284738876 17.9712026078 18.0162515102 169
# M_0
#  11.1149267354 11.2342278641 11.3202234688 157
# alpha
#  0.661528531974 1.1171114059 1.65712534398 129
# gamma
#  0.230479100259 0.306917701598 0.386266102919 187
# L_0
#  17.9489096025 18.0107237758 18.0347406805 169
# M_0
#  10.9458934911 10.9955860989 11.2311360109 127
# alpha
#  0.500433798504 0.608507100483 1.15265422975 125
# gamma
#  0.180411052195 0.223870047695 0.301335171672 175
# L_0
#  17.9443284914 17.9944371259 18.0284321334 169
# M_0
#  10.9077879687 11.0624080356 11.301398956 127
# alpha
#  0.690597636171 0.842208582997 1.16772002346 125
# gamma
#  0.185325896188 0.252230828967 0.367005965826 164
# L_0
#  17.8955909159 17.9697943776 18.0423890172 176
# M_0
#  10.1625492255 10.5939016164 11.27060515 121
# alpha
#  0.0662026023056 0.650900750691 0.960391413424 152
# gamma
#  0.0496564988309 0.148024408049 0.292266214484 140
# L_0
#  17.933589729 17.9474325396 18.0538713508 158
# M_0
#  10.7318138958 10.8269155942 11.2885479343 131
# alpha
#  0.253373989565 0.806950628723 0.979183210485 118
# gamma
#  0.13176027687 0.166692264753 0.276598610365 180
# L_0
#  17.9593615003 18.0029600859 18.0260706409 247
# M_0
#  10.9334053205 10.9687520871 11.1394980415 152
# alpha
#  0.622756116871 0.692614464578 1.05050498112 134
# gamma
#  0.2107672359 0.241236242106 0.312690281352 205
# L_0
#  17.9001836428 18.0237489411 18.0266465976 153
# M_0
#  10.6889744674 11.3138308121 11.3796848705 131
# alpha
#  0.447821248071 0.464784441169 0.900544026409 121
# gamma
#  0.0937702963204 0.267000804625 0.307330420628 146
# L_0
#  17.9090637268 17.9524985675 18.0378218425 158
# M_0
#  10.538578016 10.7711746711 11.1314296693 151
# alpha
#  0.407293569182 0.929566836012 0.94568437398 121
# gamma
#  0.107493477259 0.18512485091 0.259789039948 141
# L_0
#  17.78884936 17.8012559725 17.9888284768 145
# M_0
#  10.6343058171 10.6680446887 11.1226149966 154
# alpha
#  0.573507965755 1.61748247334 1.64422305031 124
# gamma
#  0.0328379789193 0.0450742905082 0.205956171545 145
# L_0
#  17.9737753942 18.0591149191 18.0823091601 158
# M_0
#  10.5281869458 10.6874583487 11.2798920279 121
# alpha
#  0.000221314648863 0.199855595967 0.817389639884 128
# gamma
#  0.0142861865551 0.165359782538 0.288103928287 141
# L_0
#  18.0021611885 18.0771914633 18.0891868523 211
# M_0
#  10.9546641127 11.6576638076 11.6896406043 127
# alpha
#  0.148246763869 0.202093577727 0.634015439549 136
# gamma
#  0.146281389023 0.216761589766 0.316957315806 146
# L_0
#  17.9510389363 17.9687601274 18.0447072582 203
# M_0
#  11.0621305886 11.1328864499 11.3172201591 141
# alpha
#  0.246558985752 0.784558753928 0.897463903234 145
# gamma
#  0.219514161261 0.246409358847 0.310536091455 201
# L_0
#  17.9822049094 18.0222450643 18.0412917826 208
# M_0
#  10.8933606444 10.9752735359 11.2784367534 129
# alpha
#  0.407899802072 0.549522130759 0.82805515041 125
# gamma
#  0.179128798355 0.232003019488 0.329873465283 145
# L_0
#  17.9605498493 17.9820984975 18.018053312 196
# M_0
#  11.0887811321 11.1671859114 11.2744035942 134
# alpha
#  0.740376761659 1.15751702285 1.28659445148 121
# gamma
#  0.178723213771 0.272775012745 0.331513705279 156
# L_0
#  17.9127044697 17.9371522545 18.0233216892 161
# M_0
#  10.8189157344 10.8459170245 11.2712178778 122
# alpha
#  0.671446283779 0.92336839603 1.21980931552 136
# gamma
#  0.119135639614 0.146713740301 0.293723100687 141
# L_0
#  17.8969112489 17.9803471505 18.0255159155 163
# M_0
#  10.5001919541 11.1672117886 11.2674081785 126
# alpha
#  0.519001349961 0.957760180717 1.09496423886 118
# gamma
#  0.120691126438 0.282461672837 0.289281819454 139
# L_0
#  17.944331485 18.0072791795 18.0238322805 193
# M_0
#  11.0192496829 11.353856495 11.4260141985 131
# alpha
#  0.709929774652 0.838473104931 0.993633440693 126
# gamma
#  0.140957152783 0.363003511192 0.401072515249 132
# L_0
#  17.7627293312 17.7974801699 18.0050837567 140
# M_0
#  10.0085382568 10.3880608488 11.2536889528 120
# alpha
#  0.765588439665 1.73348764613 1.99944528669 126
# gamma
#  8.97497803146e-05 0.0360526043108 0.299489923275 141
# L_0
#  17.9915931925 18.0136665177 18.0518848221 245
# M_0
#  11.0104834592 11.1012077441 11.2925225366 126
# alpha
#  0.575609148555 0.812495676872 0.91484285489 132
# gamma
#  0.22471355105 0.29816257198 0.371048752918 187
# L_0
#  17.9719518261 18.056674262 18.0784579133 166
# M_0
#  10.9711421986 11.2138976612 11.5225485866 118
# alpha
#  0.000942132768754 0.176529329764 0.803761908677 128
# gamma
#  0.166673654664 0.225742065812 0.290699966777 167
# L_0
#  17.9751529243 17.9956673256 18.0410646575 192
# M_0
#  10.8609502787 10.8751200091 11.3739698016 126
# alpha
#  0.426186419388 0.457628263914 0.857940336987 128
# gamma
#  0.123120038181 0.137664223844 0.314217921347 156
# L_0
#  17.8532080601 17.9506359685 18.0199164369 147
# M_0
#  10.5011082753 10.9536876943 11.2816117669 123
# alpha
#  0.652303280024 0.947833744586 1.19178311755 127
# gamma
#  0.0616110828046 0.197900926171 0.319093808701 140
# L_0
#  17.9756486897 18.0032887194 18.0885362073 154
# M_0
#  10.7895495801 10.8943313694 11.2582384084 130
# alpha
#  0.000102622276864 0.527678539323 0.855893151313 120
# gamma
#  0.1334580651 0.20347638534 0.316925290316 157
# L_0
#  17.8406152307 17.9812122125 18.0121020001 135
# M_0
#  10.6960347732 11.1379828842 11.2559132316 118
# alpha
#  0.678004656451 0.79064368122 1.23444640733 125
# gamma
#  0.0634444136838 0.251782575901 0.310416381648 129
# L_0
#  18.004008722 18.0620652862 18.0844039301 240
# M_0
#  10.4830161033 10.8691163691 11.3616351268 125
# alpha
#  0.083470558053 0.12364526393 0.750584176417 133
# gamma
#  0.0751476180824 0.108511463322 0.367061491835 126
# L_0
#  17.9542473885 18.0485659746 18.0562470337 167
# M_0
#  10.880647518 10.8995538196 11.2238331145 148
# alpha
#  0.257911884864 0.272486149658 1.02846973688 160
# gamma
#  0.170195891799 0.178342209682 0.274319776544 191
# L_0
#  17.9752334525 18.0100839541 18.0263765986 254
# M_0
#  11.1634699966 11.3145971539 11.3879323314 132
# alpha
#  0.407472825545 0.574078303366 0.764921237789 131
# gamma
#  0.247319260704 0.296363499554 0.31476735687 302
# L_0
#  17.9808696323 17.990257828 18.067717601 184
# M_0
#  11.0440020076 11.0681488226 11.8723271299 124
# alpha
#  0.234139530875 0.732601272285 0.832326621337 121
# gamma
#  0.197098243801 0.207520886491 0.403450015152 146
# L_0
#  17.9840424318 18.0066517786 18.0465656067 211
# M_0
#  10.9653330232 11.0693837204 11.3792871458 120
# alpha
#  0.511890093579 0.736334257712 0.889573621537 136
# gamma
#  0.232152007691 0.26792359512 0.368720728284 217
# L_0
#  17.9894967327 18.0208473583 18.0299940594 288
# M_0
#  11.0368465315 11.375513316 11.4148833803 129
# alpha
#  0.480234500506 0.573125053931 0.788156833352 133
# gamma
#  0.222328680343 0.352765237426 0.399444717159 165
# L_0
#  17.9781817465 18.0005391134 18.0545452394 190
# M_0
#  10.9655865545 11.0485433779 11.4758217907 123
# alpha
#  0.320025037793 0.58679968882 0.82625363726 131
# gamma
#  0.169638770775 0.206009121073 0.387548936975 138
# L_0
#  17.9130572872 17.953713789 18.0024675605 199
# M_0
#  10.4527472219 10.6003543285 11.2701135351 125
# alpha
#  0.470130055591 0.58194203545 1.08368171957 117
# gamma
#  0.10714487253 0.128620619472 0.301361786741 160
# L_0
#  17.8728078782 17.9604151139 18.0163119499 154
# M_0
#  10.1912830145 10.9502842106 11.1492845283 130
# alpha
#  0.403193126156 0.806434114831 0.947422391238 127
# gamma
#  0.0555294344853 0.195369535202 0.240196960568 145
# L_0
#  17.9963082521 18.0442735762 18.0526165043 254
# M_0
#  11.1496004863 11.6818971445 11.6952593696 127
# alpha
#  0.0988241458162 0.113739431441 0.819677697003 132
# gamma
#  0.132770815531 0.176414405501 0.38117421842 146
# L_0
#  17.9857986945 18.0438570796 18.0487718995 262
# M_0
#  11.1739245724 11.4685483893 11.5689957917 125
# alpha
#  0.406127070818 0.495300735322 0.963363756695 136
# gamma
#  0.273508263919 0.38588840454 0.404616527837 249
# Dust Extinction ON
# /Users/flgomezc/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.py:423: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_num_figures`).
#   max_open_warning, RuntimeWarning)
