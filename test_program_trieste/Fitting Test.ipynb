# %%
# %pylab inline
from random import *
from observational_data import *
from constants import *
from functions import *
# Out:
# Populating the interactive namespace from numpy and matplotlib
# observational_data.py:80: RuntimeWarning: invalid value encountered in log10
#   Obs_data2_log10yerror = [array(log10(Bouwens[:,1]/(Bouwens[:,1]-Bouwens[:,2]))),

# %%
# Box Size in Mpc. Must be divided by the hubble parameter in 
# the 2013 Planck cosmology. (hpl defined in "constants.py")
BoxLength = 250 / hpl
### Number of box to study

L_0   = 10.0**(17.9751116962)
M_0   = 10.0**(11.3847031963)
beta  =  0.710087628845
gamma =  0.172959910497

BOX = 13

# %%
SH = SingleHistogram( BoxLength, BOX, L_0, M_0, beta, gamma)

# %%
SH
# Out:
# [array([  9.96007102e-08,   5.01987580e-06,   6.07365131e-05,
#           3.44419256e-04,   1.26797680e-03])]

# %%
HIST0_bins
# Out:
# [-23.5, -22.5, -21.5, -20.5, -19.5, -18.5]

# %%
STR = '../data/MD_3840_Planck1/BDM/Small_Cells/'+str(BOX)+'.dat'
M = np.loadtxt(STR,usecols=(3,), skiprows=0)
########## Halo mass must be divided by the Hubble Parameter###
M = (1.0*M)/hpl                                               #
###############################################################
L = zeros(M.size)
L[:] = Luminosity(M[:], L_0, M_0, beta, gamma)
Magnitude_UV_galaxy_list = 51.82 - 2.5 * np.log10(L[:])

# %%
HIST = histogram(Magnitude_UV_galaxy_list, HIST0_bins)
print HIST[1]
# Out:
# [-23.5 -22.5 -21.5 -20.5 -19.5 -18.5]

# %%
figure(figsize(9,7))
plot()
ylabel(r"$\Phi(M_{1350})($ Mpc$^{-3}$mag$^{-1})$",fontsize=20)
xlabel('$M_{1350}$',fontsize=20)
plt.grid(True)
title("Cosmic Variance",fontsize=25)
tick_params(axis="both", labelsize=15)


scatter( Obs_data0[:,0] , SH[0],s=10, color="red", label="MCMC")
#scatter( Obs_data1[:,0] , SH[0],s=10, color="red")
#scatter( Obs_data2[:,0] , SH[1],s=10, color="black")
#scatter( Obs_data3[:,0] , SH[2],s=10, color="blue")

plot( Obs_data0[:,0] , 10**Obs_data0[:,1], "b-", label="Model" )
#errorbar(Obs_data2[:,0],Obs_data2[:,1], xerr=Obs_data2xerror, yerr=Obs_data2yerror, fmt='.', color="0.40", label="Bouwens et al 2014")
#errorbar(Obs_data1[:,0],Obs_data1[:,1], xerr=0.25, yerr=Obs_data1yerror, fmt='.', color="0.40", label="Willott et al 2013")
#errorbar(Obs_data3[:,0],Obs_data3[:,1], xerr=Obs_data3xerror, yerr=Obs_data3yerror, fmt='.', color="0.40", label="McLure et al 2009")
legend(loc=4)
plt.axis([-24.5,-18,10**-9,0.01])
yscale("log")

# %% [markdown]
# # MCMC TEST
#
# In LF$^2$ units:
#
#
# $\chi^2 = 7.52\times10^{-5}$

# %% [markdown]
# ##Fitting
# $L_0   = 10.0^{17.9751116962}$
#
# $M_0   = 10.0^{11.3847031963}$
#
# $\beta  =  0.710087628845$
#
# $\gamma =  0.172959910497$
#
# ##Model
# $L_0   = 10.0^{17.94}$
#
# $M_0   = 10.0^{11.25}$
#
# $beta  =  0.8$
#
# $gamma =  0.1424$
