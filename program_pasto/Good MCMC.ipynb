# %%
# Last modification: 2014-sep-03 Bogota
# %pylab inline
from random import *
from observational_data import *
from constants import *
from functions import *
# Out:
# Populating the interactive namespace from numpy and matplotlib
# observational_data.py:62: RuntimeWarning: divide by zero encountered in divide
#   Obs_data2_log10yerror = [array(log10(Bouwens[:,1]/(Bouwens[:,1]-Bouwens[:,2]))),

# %%
# Open the raw data from Markov Chain-MoteCarlo
# L_0 	 M_0 	 beta 	 gamma 	 chi_sqr 	 Number of Bins
if (Dust_Ext == 1):
    MCMC_raw = np.loadtxt('results_w_ext/0BB.dat',usecols=(0,1,2,3,4,5),skiprows=0); 
else:
    MCMC_raw = np.loadtxt('results_wo_ext/13.dat',usecols=(0,1,2,3,4,5),skiprows=0); 
BoxLength = 250.0 # Mpc h^{-1}

index = where( MCMC_raw[:,4] == MCMC_raw[:,4].min() )[0] 
L_min     = MCMC_raw[index,0][0]
M_min     = MCMC_raw[index,1][0]
beta_min  = MCMC_raw[index,2][0]
gamma_min = MCMC_raw[index,3][0]
bins      = MCMC_raw[index,5][0]

print L_min, M_min, beta_min ,gamma_min, bins

histo_0 = histogram(MCMC_raw[:,0], bins=30)
histo_1 = histogram(MCMC_raw[:,1], bins=30)
histo_2 = histogram(MCMC_raw[:,2], bins=30)
histo_3 = histogram(MCMC_raw[:,3], bins=30)

Lm = where( histo_0[0]==histo_0[0].max())[0][0]
Mm = where( histo_1[0]==histo_1[0].max())[0][0]
Bm = where( histo_2[0]==histo_2[0].max())[0][0]
Gm = where( histo_3[0]==histo_3[0].max())[0][0]

#Centro de la caja
LM = (histo_0[1][Lm]+ histo_0[1][Lm+1])/2.0
MM = (histo_1[1][Mm]+ histo_1[1][Mm+1])/2.0
BM = (histo_2[1][Bm]+ histo_2[1][Bm+1])/2.0
GM = (histo_3[1][Gm]+ histo_3[1][Gm+1])/2.0

print LM, MM, BM, GM
# Out:
# 18.0967366392 11.6857780318 0.768979195724 0.400981959499 18.0
# 18.1119297429 11.6811487179 0.73783759458 0.453038089345

# %%
plot( MCMC_raw[:,4] )
yscale("log")
ylabel("$\chi^2$", fontsize=20)
xlabel("MCMC steps", fontsize=20)

# %%
############## Scattering plots ########################

fig = figure(figsize=(10, 5))
fig.subplots_adjust(hspace=0.20, wspace=0.0,top=1.5, right=1.0, bottom=0.0)
ax1 = fig.add_subplot(221)
ax1.scatter(MCMC_raw[:,0], MCMC_raw[:,4], s=0.1)
ax1.set_xlabel("$\log_{10}(L_0)$",fontsize=20)
ax1.set_ylabel(" $\chi^2$ ",fontsize=20)
#ax1.set_ylim(0,5)
ax1.axis((17.6,18.2,0.7,1.2))
#ax1.set_yscale=("log")


ax2 = fig.add_subplot(222)
ax2.scatter(MCMC_raw[:,1], MCMC_raw[:,4], s=0.1)
ax2.set_xlabel("$\log_{10}(M_0)$",fontsize=20)
#ax2.set_ylabel(" $\chi^2$ ",fontsize=20)
#ax2.set_ylim(0,5)
ax2.axis((10.5,12.6,0.7,1.2))
#ax2.set_yscale=("log")
ax2.yaxis.set_major_formatter(plt.NullFormatter())

ax3 = fig.add_subplot(223)
ax3.scatter(MCMC_raw[:,2], MCMC_raw[:,4], s=0.1)
ax3.set_xlabel(r" $\beta $  ",fontsize=20)
ax3.set_ylabel(" $\chi^2$ ",fontsize=20)
ax3.axis((0.0,2.0,0.7,1.2))
#ax3.set_ylim(0,5)
#ax3.set_yscale=("log")
#ax.yaxis.set_major_formatter(plt.NullFormatter())

ax4 = fig.add_subplot(224)
ax4.scatter(MCMC_raw[:,3], MCMC_raw[:,4], s=0.1)
ax4.set_xlabel(r"$\gamma$",fontsize=20)
#ax4.set_ylabel(" $\chi^2$ ",fontsize=20)
ax4.yaxis.set_major_formatter(plt.NullFormatter())
ax4.axis((0.0,1.0,0.7,1.2))
#ax4.set_yscale=("log")



################## Histograms #############################

fig = figure(figsize=(10, 5))
fig.subplots_adjust(hspace=0.20, wspace=0.0,top=1.5, right=1.0, bottom=0.0)

ax1 = fig.add_subplot(221)
ax1.hist(MCMC_raw[:,0],bins=30)

ax2 = fig.add_subplot(222)
ax2.hist(MCMC_raw[:,1],bins=30)

ax3 = fig.add_subplot(223)
ax3.hist(MCMC_raw[:,2],bins=30)

ax4 = fig.add_subplot(224)
ax4.hist(MCMC_raw[:,3],bins=30)

ax1.axvline(x=L_min, color="blue")
#ax1.axvline(x=percentile(MCMC_raw[:,0], q=50), color="red")
#ax1.axvline(x=percentile(MCMC_raw[:,0], q=25), color="green")
#ax1.axvline(x=percentile(MCMC_raw[:,0], q=75), color="green")

ax2.axvline(x=M_min, color="blue"); 
#ax2.axvline(x=percentile(MCMC_raw[:,1], q=50), color="red")
#ax2.axvline(x=percentile(MCMC_raw[:,1], q=25), color="green")
#ax2.axvline(x=percentile(MCMC_raw[:,1], q=75), color="green")

ax3.axvline(x=beta_min, color="blue"); 
ax3.axvline(x=percentile(MCMC_raw[:,2], q=50), color="red")
ax3.axvline(x=percentile(MCMC_raw[:,2], q=25), color="green")
ax3.axvline(x=percentile(MCMC_raw[:,2], q=75), color="green")

ax4.axvline(x=gamma_min, color="blue");
ax4.axvline(x=percentile(MCMC_raw[:,3], q=50), color="red")
ax4.axvline(x=percentile(MCMC_raw[:,3], q=25), color="green")
ax4.axvline(x=percentile(MCMC_raw[:,3], q=75), color="green")

ax1.set_xlabel("$\log_{10}(L_0)$",fontsize=20)
ax2.set_xlabel("$\log_{10}(M_0)$",fontsize=20)
ax3.set_xlabel(r" $\beta $  ",fontsize=20)
ax4.set_xlabel(r"$\gamma$",fontsize=20)

print " Using '>' sign"
# Out:
#  Using '>' sign

# %%
############## Scattering plots ########################

fig = figure(figsize=(10, 5))
fig.subplots_adjust(hspace=0.3, wspace=0.3,top=1.5, right=1.0, bottom=0.0)

ax1 = fig.add_subplot(331) # L* vs M*
ax1.scatter(MCMC_raw[:,0], MCMC_raw[:,1], s=0.01)
ax1.set_xlabel("$\log_{10}(L_0)$",fontsize=20)
ax1.set_ylabel(" $\log_{10}(M_0)$ ",fontsize=20)

ax2 = fig.add_subplot(332) # L* vs beta
ax2.scatter(MCMC_raw[:,0], MCMC_raw[:,2], s=0.1)
ax2.set_xlabel("$\log_{10}(L_0)$",fontsize=20)
ax2.set_ylabel(r" $\beta $  ",fontsize=20)

ax3 = fig.add_subplot(333) # L* vs gamma
ax3.scatter(MCMC_raw[:,0], MCMC_raw[:,3], s=0.1)
ax3.set_xlabel(r" $\beta $  ",fontsize=20)
ax3.set_ylabel(" $\gamma$ ",fontsize=20)

#ax3.set_ylim(0,5)
#ax3.set_yscale=("log")
#ax.yaxis.set_major_formatter(plt.NullFormatter())

ax4 = fig.add_subplot(335)
ax4.scatter(MCMC_raw[:,1], MCMC_raw[:,2], s=0.1)
ax4.set_xlabel(r"$\log_{10}(M_0)$",fontsize=20)
ax4.set_ylabel(r"$\beta$",fontsize=20)

ax5 = fig.add_subplot(336)
ax5.scatter(MCMC_raw[:,1], MCMC_raw[:,3], s=0.1)
ax5.set_xlabel(r"$\log_{10}(M_0)$",fontsize=20)
ax5.set_ylabel(r"$\gamma$",fontsize=20)

ax6 = fig.add_subplot(339)
ax6.scatter(MCMC_raw[:,2], MCMC_raw[:,3], s=0.1)
ax6.set_xlabel(r"$\beta$",fontsize=20)
ax6.set_ylabel(r"$\gamma$",fontsize=20)

# %%
# x and y position of the points
x = MCMC_raw[:,0] 
y = MCMC_raw[:,1]
 
# Estimate the 2D histogram
nbins = 100
H, xedges, yedges = np.histogram2d(x,y,bins=nbins)
 
# H needs to be rotated and flipped
H = np.rot90(H)
H = np.flipud(H)
 
# Mask zeros
#Hmasked = np.ma.masked_where(H==0,H) # Mask pixels with a value of zero
Hmasked = H
 
# Plot 2D histogram using pcolor
fig2 = plt.figure(figsize=(10, 8))
plt.pcolormesh(xedges,yedges,Hmasked)
plt.xlabel('x')
plt.ylabel('y')
cbar = plt.colorbar()
cbar.ax.set_ylabel('Counts')

# %%
figure(figsize=(10, 8))
XX = zeros(xedges.size -1)
YY = zeros(yedges.size -1)
for i in range(XX.size):
    XX[i] = 0.5*(xedges[i] + xedges[i+1])
for i in range(YY.size):
    YY[i] = 0.5*(yedges[i] + yedges[i+1])
    
contourf( XX,YY, H)
# Out:
# <matplotlib.contour.QuadContourSet instance at 0x65a3200>

# %%
plt.gca() #Return the current axis instance.  This can be used to control

# %%
plt.contourf(Hmasked) #Plot contours
plt.colorbar()
# Out:
# array([[ 11.25      ,  11.25      ,  11.25      , ...,  11.25      ,
#          11.25      ,  11.25      ],
#        [ 11.25      ,  11.25      ,  11.25      , ...,  11.25      ,
#          11.25      ,  11.25      ],
#        [ 11.25      ,  11.25      ,  11.25      , ...,  11.25      ,
#          11.25      ,  11.25      ],
#        ...,
#        [ 11.80810973,  11.80810973,  11.80810973, ...,  11.80810973,
#          11.80810973,  11.80810973],
#        [ 11.80810973,  11.80810973,  11.80810973, ...,  11.80810973,
#          11.80810973,  11.80810973],
#        [ 11.80810973,  11.80810973,  11.80810973, ...,  11.80810973,
#          11.80810973,  11.80810973]])
