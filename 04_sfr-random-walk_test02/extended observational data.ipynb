# %%
m%pylab inline
BINS = 6

#############################################
#                                           #
#            Loading data file              #
#                                           #
#############################################

# Data columns:
# X (Mpc h^-1), Y (Mpc h^-1), Z (Mpc h^-1), Halo mass (Solar Mass)
data = np.loadtxt(
        #'/home/flgomez10/sfr-dmhm/data/MD_3840_Planck1/BDM/small_cell_cat.dat',
        '/home/filipo/sfm-dmhm/data/MD_3840_Planck1/BDM/reduced_catshortV_007.dat',
          usecols=(0,1,2,3), skiprows=17)

BoxLength = 1000.0 # Mpc h^{-1}

# Is necesary to specify the box size for normalization
# it deppends of the used catalog.
# for small_cell_cat.dat BoxLength = 1000/4 Mpc h^-1
# for reduced_catshortV_007.dat Boxlength = 1000 h^-1
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#############################################
#                                           #
#           Observational Data              #
#                                           #
#############################################

# Observations from Willott et al,2012
Obs_data = np.array([#  Mag,LumFunct, low_err, upp_err #
                     [-22.5, 2.66E-8, 9.08E-9, 7.78E-8],
                     [-22.0, 2.18E-6, 8.70E-7, 9.70E-6],
                     [-21.5, 1.45E-5, 2.88E-6, 2.92E-5],
                     [-21.0, 1.29E-4, 7.06E-5, 2.19E-4],
                     [-20.5, 2.30E-4, 9.34E-5, 5.77E-4]])                  
Obs_data_log10 = array([  # Magnitude,log10_LumFunct
[ -22.5, -7.57511836, -8.04191415, -7.1090204 ],
[ -22.0, -5.66154351, -6.06048075, -5.01322827],
[ -21.5, -4.838632  , -5.54060751, -4.53461715],
[ -21.0, -3.88941029, -4.1511953 , -3.65955589],
[ -20.5, -3.63827216, -4.02965312, -3.23882419]])

# Observations from Bouwens et al 2006
Obs_data2= np.array([#  Mag,LumFunct, low_err, upp_err #
                        [-21.94,1.00e-5,1.00e-6,2.00e-5],
                        [-21.44,7.00e-5,3.00e-5,1.10e-4],
                        [-20.94,1.20e-4,5.00e-5,1.90e-4],
                        [-20.44,3.30e-4,1.10e-4,4.50e-4],
                        [-19.94,1.28e-3,9.80e-4,1.58e-3],
                        [-19.44,3.13e-3,1.95e-4,4.31e-3],
                        [-18.69,3.32e-3,2.17e-3,4.47e-3],
                        [-17.69,7.71e-3,5.60e-3,9.82e-3]])
Obs_data2_log10 = array([# Magnitude,log10_LumFunct
[-21.94, -5.0000000000, -6.0000000000, -4.6989700043],
[-21.44, -4.1549019600, -4.5228787453, -3.9586073148],
[-20.94, -3.9208187540, -4.3010299957, -3.7212463990],
[-20.44, -3.4814860601, -3.6777807053, -3.3467874862],
[-19.94, -2.8927900304, -3.0087739243, -2.3685562310],
[-19.44, -2.5044556625, -2.7099653886, -2.3655227298],
[-18.69, -2.4788619163, -2.6635402662, -2.3169529618],
[-17.69, -2.1129456219, -2.2518119730, -2.0078885122]])
# Observations from Bouwens et al 2012
Obs_data3_log10 = array([#low_err, upp_err #
[-21.90, -4.537, -5.006, -4.318],
[-21.40, -4.473, -4.960, -4.242],
[-20.89, -3.717, -3.894, -3.603],
[-20.40, -3.191, -3.324, -3.093],
[-19.88, -2.968, -3.093, -2.881],
[-19.37, -2.586, -2.764, -2.458],
[-18.86, -2.443, -2.613, -2.341],
[-18.36, -2.314, -2.443, -2.193],
[-17.85, -2.137, -2.276, -2.042],
[-17.34, -2.031, -2.261, -1.864]])

# %%
# This is the Luminosity function, 
# it has four parameters and one variable, 
# the halo mass: M.

def Luminosity(M,L_0,M_0,beta,gamma):
    return L_0*M*( (M/M_0)**(-beta) + (M/M_0)**gamma)**(-1)

# This is the Star Formation Rate Function, just 

def StarFormationRate(M,L_0,M_0,beta,gamma):
    return Luminosity(M,L_0,M_0,beta,gamma) * 1.4e-28

# %% [markdown]
# # The Fitting function for Luminosity
#
# $ L(M) = L_0 M \left[ \left(\frac{M}{M^*}\right)^{-\beta} + \left(\frac{M}{M^*}\right)^{\gamma} \right]^{-1} $
#
# # The fitting funtion for Star Forming Rate
#
# $ \text{SFR}\left(M_\odot \text{yr}^{-1}\right) = 1.4 \times 10^{28} L_{\nu} \left( \text{erg s}^{-1}\text{Hz}^{-1} \right)$
#
# For each galaxy
#
# $ \textrm{SFR}(M_h) = 1.4 \times 10^{-28} \times L(M_h)$
#
# $ \textrm{SFR}(M_h) = 1.4 \times 10^{-28} L_0 M
#                           \left[ \left(\frac{M_h}{M^*}\right)^{-\beta}
#                                + \left(\frac{M_h}{M^*}\right)^{\gamma} \right]^{-1} $
#
# Magnitude: dimetionless
#
# Luminosity:  $[ \text{erg } \text{s}^{-1} \text{Hz}^{-1} ]$
#
# Star Formation Rate: $[ M_\odot \textrm{yr}^{-1} ]$

# %%
# Some necesary vectors: halo mass M, log10(M) 
# and the luminosity of each halo: L.

M       = data[:,3]
log10_M = log10(M[:])
L       = np.zeros(M.size)
L_R     = np.zeros(M.size)

SFR     = np.zeros(M.size)

random.seed([0])
################################################################
#                                                              #
#                     The Random Walk                          #
#                     fitting function                         #
#                                                              #
################################################################

# Initial constants for the luminosity function
# 17.5908958938 11.0881957561 0.889305953172 0.398344192416 0.182896419593
# 17.651076186 11.3103664009 0.863881819343 0.532187082693 0.0478280976379
L_0   = 10.0**(17.651076186)
M_0   = 10.0**(11.3103664009)
beta  =  0.863881819343
gamma =  0.532187082693

BoxLength = 1000.0 # Mpc h^{-1}
MonteCarloSteps = 0
K0 = 0.01
K1 = 0.01
K2 = 0.1
K3 = 0.1

# 4D sphere that needs 3 angles and one radius.
#random.seed([0])
phi_1 = 0.00 ;phi_2 = 0.00; phi_3 = 0.00

#Calculate the histogram and Xi_sqr for first time.
for i in range(M.size):
    L[i] = Luminosity( M[i], L_0, M_0, beta, gamma)
    SFR[i] = StarFormationRate( M[i], L_0, M_0, beta, gamma)
Magnitude_UV_galaxy_list = 51.82 - 2.5 * log10(L[:])
HIST = histogram(Magnitude_UV_galaxy_list,
                 bins=(-22.5,-22.0,-21.5,-21.0,-20.5,-20.0))[0]
HIST = HIST/( 0.5*BoxLength**3)
    
Xi_sqr=0.0
for i in range(5):
    if( HIST[i]>0):
        Xi_sqr = Xi_sqr + ( log10(HIST[i])-Obs_data_log10[i,1] )**2
    else:
        Xi_sqr = Xi_sqr + 100

# First of all, the histogram with the original parameters must be calculated,
# included the Xi_square deviation
for k in range(MonteCarloSteps):
    print k, Xi_sqr
    # Then the parameters are changed in order to calculate the new histogram
    delta_0 = random.random()
    delta_1 = random.random()
    delta_2 = random.random()
    delta_3 = random.random()

    L_0R   = L_0  *10**(K0*delta_0)
    M_0R   = M_0  *10**(K1*delta_1)
    betaR  = beta + K2*delta_2
    gammaR = gamma+ K3*delta_3

    # Now is possible to calculate the new histogram
    # and the new Xi_square deviation.
    for i in range(M.size):
        L_R[i]    = Luminosity( M[i], L_0R, M_0R, betaR, gammaR)
    Magnitude_UV_galaxy_list_R = 51.82 - 2.5 * log10(L_R[:])
    HIST_R = histogram(Magnitude_UV_galaxy_list_R,
                       bins=(-22.5,-22.0,-21.5,-21.0,-20.5,-20.0))[0]
    HIST_R = HIST_R/( 0.5*BoxLength**3)
    
    Xi_sqr_R=0.0
    for i in range(5):
        if( HIST_R[i]>0):
            Xi_sqr_R = Xi_sqr_R + ( log10(HIST_R[i])-Obs_data_log10[i,1] )**2
        else:
            Xi_sqr_R = Xi_sqr_R + 100
    #print Xi_sqr_R
    # If the new deviation is better, then accept the parameters change.
    if (Xi_sqr_R<Xi_sqr):
        L_0    = L_0R
        M_0    = M_0R
        beta   = betaR
        gamma  = gammaR
        HIST   = HIST_R
        Xi_sqr =Xi_sqr_R
# End of the loop

# %%
#figure(figsize(8,4.5))
errorbar(Obs_data[:,0],Obs_data[:,1],Obs_data[:,2],
         Obs_data[:,3],"b-",label='Observational Data - 2013')
errorbar(Obs_data2[:,0],Obs_data2[:,1],Obs_data2[:,2],
         Obs_data2[:,3],"k-",label='Observational Data2- 2007')
semilogy([-22.5, -22. , -21.5, -21. , -20.5],HIST,"r-o", label='Fitting for Obs. Data - 2013')
#semilogy([-22.5, -22. , -21.5, -21. , -20.5],HIST_R,"g-o", label='F_RW')
ylabel(r"$\log_{10}$ Luminosity Function")
xlabel("Magnitude")
title("Luminosity Function at z=5.9")
legend(loc=4)

# %%
CC = histogram( Magnitude_UV_galaxy_list, 
               bins=(-22.5,-22.0,-21.5,-21.0,-20.5,-20.0,-19.5,-19.0,-18.5,-18.0,-17.5,-17.0))[0]
CC = CC/( 0.5*BoxLength**3)
DD = [-22.5,-22.0,-21.5,-21.0,-20.5,-20.0,-19.5,-19,-18.5,-18.0,-17.5]

# %%
Obs_data2= np.array([#  Mag,LumFunct, low_err, upp_err #
                        [-21.94,1.00e-5,0.99e-5,0],
                        [-21.44,7.00e-5,4.00e-5,0],
                        [-20.94,1.20e-4,7.00e-5,0],
                        [-20.44,3.30e-4,1.20e-4,0],
                        [-19.94,1.28e-3,0.30e-3,0],
                        [-19.44,3.13e-3,1.18e-3,0],
                        [-18.69,3.32e-3,1.15e-3,0],
                        [-17.69,7.71e-3,2.11e-3,0]])

Obs_data3_log10= np.array([
[-21.90,-4.537,-5.0, -4.318],
[-21.40,-4.473,-0.487, -4.242],
[-20.89,-3.717,-0.177, -3.603],
[-20.40,-3.191,-0.133, -3.093],
[-19.88,-2.968,-0.125, -2.881],
[-19.37,-2.586,-0.178, -2.458],
[-18.86,-2.443,-0.17 , -2.341],
[-18.36,-2.314,-0.129, -2.193],
[-17.85,-2.137,-0.139, -2.042],
[-17.34,-2.031,-0.23 , -1.864]])

figure(figsize(6,4.5))
semilogy(DD,CC,"g")
errorbar(Obs_data[:,0],Obs_data[:,1],Obs_data[:,2],Obs_data[:,3],
         "bo",label='Observational Data - 2013')
errorbar(Obs_data2[:,0],Obs_data2[:,1],Obs_data2[:,2],Obs_data2[:,3],
         "ko",label='Observational Data2- 2007')
errorbar(Obs_data3_log10[:,0],10**Obs_data3_log10[:,1],10**Obs_data3_log10[:,2],
         10**Obs_data3_log10[:,3],
        "ro",label='Observational Data3- 2012',linewidth=1)
ylabel(r"$\log_{10}$ LF",fontsize=20)
yscale("log")
xlabel("Magnitude",fontsize=20)
axis([-23,-16,0.8e-6,1.6e-2])
title("Luminosity Function at z=5.9",fontsize=20)

legend(loc=4)

# %%
Obs_data3_log10[9,:]
# Out:
# array([-17.34 ,  -2.031,  -0.23 ,  -1.864])

# %%
figure(figsize(6,4.5))
semilogy(DD,CC,"g")
errorbar(Obs_data[:,0],Obs_data[:,1],Obs_data[:,2],Obs_data[:,3],
         "bo",label='Observational Data - 2013')
errorbar(Obs_data2[:,0],Obs_data2[:,1],Obs_data2[:,2],Obs_data2[:,3],
         "ko",label='Observational Data2- 2007')
errorbar(Obs_data3_log10[:,0],10**Obs_data3_log10[:,1],10**Obs_data3_log10[:,2],
         10**Obs_data3_log10[:,3],
        "ro",label='Observational Data3- 2012',linewidth=1)
ylabel(r"$\log_{10}$ LF",fontsize=20)
yscale("log")
xlabel("Magnitude",fontsize=20)
axis([-23,-16,0.8e-6,1.6e-2])
title("Luminosity Function at z=5.9",fontsize=20)

legend(loc=4)

# %%
HIST2 = histogram(SFR,bins=10)[0]
histogram(SFR,bins=10)[1]
HIST2_bins = [  0.09662371,   6.22997201,  12.36332032,  18.49666862,
        24.63001693,  30.76336523,  36.89671354,  43.03006184,
        49.16341015,  55.29675845]

# %%
semilogy(HIST2 , HIST2_bins)
xlabel("Star Formation Rate $M_\odot$")

# %%
L_0   = 10.0**(17.651076186)
M_0   = 10.0**(11.3103664009)
beta  =  0.863881819343
gamma =  0.532187082693

Mass = linspace(10,14,20)
SFR2 = zeros(Mass.size)

for i in range(Mass.size):
    SFR2[i] = StarFormationRate(10**Mass[i],L_0,M_0,beta,gamma)
           
loglog(10**Mass,SFR2,"r-o")
