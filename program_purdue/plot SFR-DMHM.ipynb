# %%
# Last modification: 2015-feb-08 West Lafayette
# %pylab inline
from random import *
from observational_data import *
from constants import *
from functions import *
# Out:
# Populating the interactive namespace from numpy and matplotlib
# observational_data.py:58: RuntimeWarning: divide by zero encountered in divide
#   Obs_data2_log10yerror = [array(log10(Bouwens[:,1]/(Bouwens[:,1]-Bouwens[:,2]))),

# %%
Dust_Ext = 0

# %%
MassRange = logspace(10,13,20)

Parameters=[]
for i in range(1,5):
    if (Dust_Ext == 1):
        Parameters.append(np.loadtxt('analysis/best_parameters_w_ext OD'+str(i)+'.dat',usecols=(0,1,2,3),skiprows=1))
    else:
        Parameters.append(np.loadtxt('analysis/best_parameters_wo_ext OD'+str(i)+'.dat',usecols=(0,1,2,3),skiprows=1))
Dust_Extinction()
Parameters = np.array(Parameters)




Mass = logspace(10,13,20)
SFR = []

L_0   = 10**Parameters[:,:,0]
M_0   = 10**Parameters[:,:,1]
beta  = Parameters[:,:,2]
gamma = Parameters[:,:,3]

for i in range(0,4):
    aux=[]
    for j in range(0,64):
        aux.append(StarFormationRate(Mass, L_0[i][j], M_0[i][j], beta[i][j], gamma[i][j]))
    aux=array(aux)
    SFR.append(aux)
SFR = array(SFR)



SFR_avrg = np.zeros([4,20])
SFR_1qrt = np.zeros([4,20])
SFR_3qrt = np.zeros([4,20])

for i in range(0,4):
    for j in range(0,Mass.size):
        SFR_avrg[i,j] = average(SFR[i,:,j])
        SFR_1qrt[i,j] = percentile(SFR[i,:,j],25)
        SFR_3qrt[i,j] = percentile(SFR[i,:,j],75)
# Out:
# Dust Extinction OFF

# %%
colors=['blue','red','green','black']
authors=[OD1[3], OD2[3], OD3[3], OD4[3]]

figure(figsize=(9,7))
    
for i in range(0,4):
    plot(Mass,SFR_avrg[i],color=colors[i], label=authors[i])
    fill_between(Mass,SFR_1qrt[i],SFR_3qrt[i], facecolor=colors[i],alpha=0.3)
    plt.yscale('log', nonposy='clip')
    plt.xscale('log')
legend(loc='upper left')

ylim([10**-2,10**4])
xlabel("DMH mass$[M_\odot]$", fontsize=20)
ylabel("SFR $[M_\odot yr^{-1}]$", fontsize=20)

Dust_Extinction()
if Dust_Ext == 1:    title('Dust Extinction Model', fontsize=24); savefig('analysis/SFR_DMHM_w.pdf')
else:                title('No Dust Extinction Model', fontsize=24); savefig('analysis/SFR_DMHM_wo.pdf')
# Out:
# Dust Extinction OFF
